# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup 

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])

# %% [markdown]
# ## Retrieving Articles Only

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup 
import re

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    if 'href' in link.attrs:
        print(link.attrs['href'])

# %% [markdown]
# ## Random Walk

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

random.seed(datetime.datetime.now())
def getLinks(articleUrl):
    html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))

links = getLinks('/wiki/Kevin_Bacon')
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/Nickelodeon_(Croatian_TV_channel)
# /wiki/Simon_%26_Schuster
# /wiki/Gulf_and_Western_Industries
# /wiki/Nickelodeon_(Brazilian_TV_channel)
# /wiki/AXS_TV
# /wiki/MLB.com#MLB.tv
# /wiki/Speed_(TV_network)
# /wiki/Aero_Warriors
# /wiki/Generation_2_(NASCAR)
# /wiki/List_of_the_closest_NASCAR_Xfinity_Series_finishes
# /wiki/Kyle_Busch
# /wiki/David_Ragan
# /wiki/2015_Goody%27s_Headache_Relief_Shot_500
# /wiki/Matt_Kenseth
# /wiki/Jeff_Gordon
# /wiki/Los_Angeles_Times
# /wiki/William_Prochnau
# /wiki/Washington,_DC
# /wiki/Freddie_Mac
# /wiki/Deed
# /wiki/Real_estate_bubble
# /wiki/Spanish_property_bubble
# /wiki/Spanish_cuisine
# /wiki/Couscous
# /wiki/Harissa
# /wiki/Bsisa
# /wiki/Yapchik
# /wiki/Havdalah
# /wiki/Shabbat
# /wiki/Assyriologist
# /wiki/Biblical
# /wiki/Ecclesiastes
# /wiki/Book_of_Jonah
# /wiki/Pauline_epistles
# /wiki/Paphos
# /wiki/Strovolos
# /wiki/Exometochi
# /wiki/Katokopia
# /wiki/Turkish_language
# /wiki/Tindi_language
# /wiki/Tsez_language
# /wiki/Avar_language
# /wiki/Voiced_velar_plosive
# /wiki/ISBN_(identifier)
# /wiki/Fiber_Distributed_Data_Interface
# /wiki/Ethernet
# /wiki/Digital_subscriber_line
# /wiki/Two-binary,_one-quaternary
# /wiki/Carrier-suppressed_return-to-zero
# /wiki/Baud
# /wiki/Gross_bit_rate
# /wiki/Videoconferencing
# /wiki/Video_camera
# /wiki/S2CID_(identifier)
# /wiki/Human%E2%80%93computer_interaction
# /wiki/Group_work
# /wiki/Amartya_Sen
# /wiki/Cambridge_Apostles
# /wiki/Cambridge_University_Wine_Society
# /wiki/Department_of_Anglo-Saxon,_Norse_and_Celtic,_University_of_Cambridge
# /wiki/Cambridge_University_Lawn_Tennis_Club
# /wiki/Centre_for_India_%26_Global_Business
# /wiki/MRC_Cognition_and_Brain_Sciences_Unit
# /wiki/Tilli_Tansey
# /wiki/Fellow_of_the_Academy_of_Medical_Sciences
# /wiki/United_Kingdom
# /wiki/United_Nations_Security_Council
# /wiki/Reform_of_the_United_Nations
# /wiki/Costa_Rica
# /wiki/Costa_Rica_at_the_Olympics
# /wiki/Swimming_at_the_2000_Summer_Olympics_%E2%80%93_Women%27s_200_metre_freestyle
# /wiki/Wang_Luna
# /wiki/Wang_(surname)
# /wiki/Wang_Jinrei
# /wiki/Kuma_and_Panda
# /wiki/Tekken_7
# /wiki/Asuka_Kazama
# /wiki/Tekken_(video_game)
# /wiki/Namco
# /wiki/Video_game_industry
# /wiki/Entertainment_Software_Association
# /wiki/Square_Enix
# /wiki/Hoya_Corporation
# /wiki/Val_Saint_Lambert
# /wiki/Holmegaard_Glass_Factory
# /wiki/Jacob_E._Bang
# /wiki/ISBN_(identifier)
# /wiki/ISO_10628
# /wiki/ISO_4165
# /wiki/Quality_function_deployment
# /wiki/ISO_10962
# /wiki/Prolog
# /wiki/Doi_(identifier)
# /wiki/Indecs_Content_Model
# /wiki/Media_(communication)
# /wiki/H.L._Mencken
# /wiki/The_American_Language
# /wiki/OCLC_(identifier)
# /wiki/Innovative_Interfaces
# /wiki/Subsidiary
# /wiki/Xerox
# /wiki/Rochester_metropolitan_area,_New_York
# /wiki/Xerox
# /wiki/Xerox_1200
# /wiki/Xerox
# /wiki/Fuji_Xerox
# /wiki/Sega
# /wiki/Eurogamer
# /wiki/Holding_company
# /wiki/Systems_management
# /wiki/Chartered_Management_Institute
# /wiki/United_Kingdom
# /wiki/Queen_of_Ghana
# /wiki/Wilding_series
# /wiki/Princess_Elizabeth_and_Philip_Mountbatten%27s_wedding_cakes
# /wiki/Spitting_Image
# /wiki/Ronald_Reagan_1976_presidential_campaign
# /wiki/Jimmy_Carter_1976_presidential_campaign
# /wiki/Jimmy_Carter_judicial_appointment_controversies
# /wiki/Jimmy_Carter_(film)
# /wiki/Peter_Bourne
# /wiki/Emory_University_School_of_Medicine
# /wiki/GPA
# /wiki/Academic_grading_in_Iran
# /wiki/Academic_grading_in_France
# /wiki/Second_French_Empire
# /wiki/List_of_monarchy_referendums
# /wiki/Saint_Vincent_and_the_Grenadines
# /wiki/Quatre
# /wiki/Saint_Vincent_(island)
# /wiki/St._Vincent_Island_(Florida)
# /wiki/Black_buck
# /wiki/Sika_deer
# /wiki/Philippine_warty_pig
# /wiki/Capreolus
# /wiki/Moose
# /wiki/Dermacentor_albipictus
# /wiki/Acariformes
# /wiki/Holothyrida
# /wiki/Acari
# /wiki/Scabies_mite
# /wiki/Stratum_corneum
# /wiki/Epidermis_(skin)
# /wiki/Hyperkeratosis
# /wiki/Skin
# /wiki/Amphibian
# /wiki/Elpistostege
# /wiki/Occidens_portlocki
# /wiki/Platycephalichthys
# /wiki/Tristichopteridae
# /wiki/Osteolepiformes
# /wiki/Whatcheeriidae
# /wiki/Ordovician
# /wiki/Doi_(identifier)
# /wiki/ISO/IEC_TR_12182
# /wiki/Algerian_Institute_of_Standardization
# /wiki/Standards_Norway
# /wiki/American_National_Standards_Institute
# /wiki/Fortran
# /wiki/IBM_1401
# /wiki/Core_memory
# /wiki/Eric_S._Raymond
# /wiki/Eric_Raymond_(disambiguation)
# /wiki/Eric_Scott_Raymond
# /wiki/Solar-powered_airplane
# /wiki/Building-integrated_photovoltaics
# /wiki/Doi_(identifier)
# /wiki/ISO_6438
# /wiki/ISO_31-11
# /wiki/FDI_World_Dental_Federation_notation
# /wiki/Maxillary_canine
# /wiki/Mouth
# /wiki/ISBN_(identifier)
# /wiki/MPEG-21
# /wiki/Audio_coding_format
# /wiki/John_Wiley_%26_Sons
# /wiki/United_States_dollar
# /wiki/Homelessness_in_the_United_States
# /wiki/Standard_of_living_in_the_United_States
# /wiki/Tourism_in_the_United_States
# /wiki/Fishing_industry_in_the_United_States
# /wiki/Fish_processing
# /wiki/Shrimp_marketing
# /wiki/Fish_hook
# /wiki/Tenkara_fishing
# /wiki/Glossary_of_fishery_terms
# /wiki/Benthos
# /wiki/Macrobenthos
# /wiki/Bioluminescence
# /wiki/Chemiluminescence
# /wiki/ISBN_(identifier)
# /wiki/Library_of_Congress
# /wiki/Thomas_Jefferson
# /wiki/Laissez-faire
# /wiki/Benjamin_Tucker
# /wiki/Anti-Stalinist_left
# /wiki/Besarion_Jughashvili
# /wiki/Joseph_Stalin
# /wiki/Joint_State_Political_Directorate
# /wiki/People%27s_Commissariat_for_Internal_Affairs
# /wiki/Ministry_of_Construction_of_Road_Building_and_Communal_Machines
# /wiki/Ministry_of_Electrical_Engineering
# /wiki/Goskomstat
# /wiki/Gosplan
# /wiki/October_Revolution
# /wiki/Leon_Trotsky
# /wiki/What_is_Fascism
# /wiki/Fritz_Julius_Kuhn
# /wiki/Webster,_Massachusetts
# /wiki/Scituate,_Massachusetts
# /wiki/Bedford,_New_Hampshire
# /wiki/Amoskeag_Falls
# /wiki/Hopkinton,_Massachusetts
# /wiki/Bedford,_New_Hampshire
# /wiki/1940_United_States_census
# /wiki/Massachusetts
# /wiki/Brockton,_Massachusetts
# /wiki/North_Pembroke,_Massachusetts
# /wiki/East_Bridgewater,_Massachusetts
# /wiki/Scituate,_Massachusetts
# /wiki/White_Island_Shores,_Massachusetts
# /wiki/Census
# /wiki/Data_collection
# /wiki/Shapiro%E2%80%93Wilk_test
# /wiki/Statistical_hypothesis_testing
# /wiki/Stationary_process
# /wiki/Stochastic_approximation
# /wiki/Forest_plot
# /wiki/ISBN_(identifier)
# /wiki/International_Standard_Identifier_for_Libraries_and_Related_Organizations
# /wiki/ISO_259
# /wiki/ISO_14698
# /wiki/ISO/IEC_27005
# /wiki/Requirements_engineering
# /wiki/Software_requirements_specification
# /wiki/IEEE_1394
# /wiki/RS-485
# /wiki/Building_automation
# /wiki/Impact_of_self-driving_cars
# /wiki/Jobless_recovery
# /wiki/Workaholic
# /wiki/Harm_reduction
# /wiki/Burning_Man
# /wiki/Nevada_State_Route_49
# /wiki/Camping
# /wiki/Quebec
# /wiki/Artificial_satellite
# /wiki/Earth_observation_satellite
# /wiki/Satellite_imagery
# /wiki/Education
# /wiki/OCLC_(identifier)
# /wiki/Dewey_Decimal_Classification
# /wiki/Faceted_classification
# /wiki/Colon_Classification
# /wiki/Drug
# /wiki/Solution_(chemistry)
# /wiki/Anaesthetic_machine
# /wiki/Richard_von_Foregger
# /wiki/Freestyle_swimming
# /wiki/Yannick_Agnel
# /wiki/United_States
# /wiki/Mississippian_culture
# /wiki/Lamar_phase
# /wiki/Sixtoe_Mound
# /wiki/Mound_Builders
# /wiki/Three-age_system#Stone_Age_subdivisions
# /wiki/John_Evans_(archaeologist)
# /wiki/Wikisource
# /wiki/Erik_M%C3%B6ller
# /wiki/Free_knowledge
# /wiki/The_Open_Source_Definition
# /wiki/Artistic_License
# /wiki/The_Free_Software_Definition
# /wiki/Mozilla_software_rebranded_by_Debian
# /wiki/Jetpack_(Firefox_project)
# /wiki/SeaMonkey
# /wiki/Netscape_(web_browser)
# /wiki/Ghostzilla
# /wiki/Redcore
# /wiki/Linux
# /wiki/IBM_AIX
# /wiki/TCP/IP
# /wiki/QUIC
# /wiki/Post_Office_Protocol
# /wiki/MIME
# /wiki/Network_File_System
# /wiki/View-source_URI_scheme
# /wiki/Opera_Coast
# /wiki/Opera_Mobile
# /wiki/QQ_browser
# /wiki/Tencent_Games
# /wiki/Stardew_Valley
# /wiki/LGBT
# /wiki/Intersex_rights_in_Switzerland
# /wiki/Zwischengeschlecht
# /wiki/Disorders_of_sex_development
# /wiki/Androgyny
# /wiki/Fraternal_birth_order_and_male_sexual_orientation
# /wiki/PMID_(identifier)
# /wiki/Research_center
# /wiki/Applied_research
# /wiki/Methodology
# /wiki/Cheondoism
# /wiki/Rastafari
# /wiki/Proselytism
# /wiki/Qatar
# /wiki/Arab_League%E2%80%93European_Union_relations
# /wiki/Euro-Latin_American_Parliamentary_Assembly
# /wiki/Croatia
# /wiki/Nature_park
# /wiki/Carinthia_(state)
# /wiki/Villach-Land_District
# /wiki/Sankt_Veit_an_der_Glan_District
# /wiki/Slovenian_language
# /wiki/Palatal_consonant
# /wiki/Phonetic_symbols_in_Unicode
# /wiki/Uralic_Phonetic_Alphabet
# /wiki/Finland
# /wiki/.eu
# /wiki/Regulation_(European_Union)
# /wiki/Euro_coins
# /wiki/Euro
# /wiki/Eurogroup
# /wiki/Greece
# /wiki/Finland
# /wiki/Edvin_Laine
# /wiki/The_Unknown_Soldier_(1955_film)
# /wiki/V%C3%A4in%C3%B6_Linna
# /wiki/For_the_Living_and_the_Dead
# /wiki/Jonas_Eika
# /wiki/Haslev
# /wiki/H%C3%B8rsholm
# /wiki/Usser%C3%B8d_Textile_Factory
# /wiki/Valler%C3%B8d
# /wiki/North_Zealand
# /wiki/Renaissance
# /wiki/Islamic_Golden_Age
# /wiki/ISBN_(identifier)
# /wiki/Whirlpool_(hash_function)
# /wiki/One-key_MAC
# /wiki/ChaCha20-Poly1305
# /wiki/Shift_register
# /wiki/Rabbit_(cipher)
# /wiki/Cryptographic_hash_function
# /wiki/Pseudorandom_number_generator
# /wiki/ANZIAM_Journal
# /wiki/Australia
# /wiki/Silent_film
# /wiki/List_of_mummy_films
# /wiki/Psychological_thriller
# /wiki/Patricia_Highsmith
# /wiki/Strangers_on_a_Train_(film)
# /wiki/Tom_Ripley
# /wiki/Confidence_trick
# /wiki/Credit_card_fraud
# /wiki/Bankruptcy_fraud
# /wiki/Law_of_the_United_States
# /wiki/State_legislature_(United_States)
# /wiki/Lee_Resolution
# /wiki/Germans_in_the_American_Revolution#Allies_of_Great_Britain
# /wiki/Peter_Muhlenberg
# /wiki/Edward_L._Stokes
# /wiki/Ray_Musto
# /wiki/Thomas_M._Tigue
# /wiki/Raphael_J._Musto
# /wiki/Pennsylvania_Senate,_District_14
# /wiki/Allentown,_Pennsylvania
# /wiki/Paper_cartridge
# /wiki/Windage
# /wiki/Deflection_shooting
# /wiki/Basketball_(ball)
# /wiki/Twenty-one_(basketball)
# /wiki/Variations_of_basketball
# /wiki/FIBA_Under-19_Basketball_World_Cup
# /wiki/United_States_men%27s_national_under-19_basketball_team
# /wiki/1979_FIBA_Under-19_World_Championship
# /wiki/FIBA_U18_European_Championship
# /wiki/Andorra_men%27s_national_under-18_basketball_team
# /wiki/FIBA_Europe
# /wiki/Luxembourg_women%27s_national_basketball_team
# /wiki/Netherlands_women%27s_national_basketball_team
# /wiki/Netherlands_women%27s_national_youth_handball_team
# /wiki/Netherlands_national_rugby_union_team
# /wiki/South_Korea_national_rugby_union_team
# /wiki/2015_Asian_Rugby_Championship
# /wiki/Oh_Youn-hyung
# /wiki/Korea_Electric_Power_Corporation
# /wiki/Korea_Gas_Corporation
# /wiki/Earnings_before_interest_and_taxes
# /wiki/Fund_accounting
# /wiki/Asset
# /wiki/Capital_equipment
# /wiki/Creative_accounting
# /wiki/Credit-linked_note
# /wiki/Amortising_swap
# /wiki/Binomial_options_pricing_model
# /wiki/Dividend_future
# /wiki/Fund_derivative
# /wiki/Margin_(finance)
# /wiki/Consumer_debt
# /wiki/Brunei
# /wiki/British_protectorate
# /wiki/Trucial_States
# /wiki/Persian_Gulf_Residency
# /wiki/Bandar_Lengeh
# /wiki/Harsin,_Hormozgan
# /wiki/Bandar-e_Lengeh_Airport
# /wiki/Maghoh
# /wiki/Rameyleh,_Hormozgan
# /wiki/Pas_Band,_Hormozgan
# /wiki/Ghadir_Saberi
# /wiki/Bakhsh
# /wiki/Bashki
# /wiki/Byty%C3%A7
# /wiki/T%C3%ABrthore
# /wiki/Kolsh,_Kuk%C3%ABs
# /wiki/Lum%C3%AB
# /wiki/Shtiq%C3%ABn
# /wiki/Bicaj
# /wiki/Arr%C3%ABn
# /wiki/Shtiq%C3%ABn
# /wiki/Arr%C3%ABn
# /wiki/Kuk%C3%ABs
# /wiki/Divjak%C3%AB
# /wiki/Fier
# /wiki/Institute_of_Statistics_(Albania)
# /wiki/Monaco_Statistics
# /wiki/Turkish_Statistical_Institute
# /wiki/Statistik_Austria
# /wiki/Federal_State_Statistics_Service_(Russia)
# /wiki/Rosreestr
# /wiki/Federal_Road_Agency_(Russia)
# /wiki/Federal_Rail_Transport_Agency_(Russia)
# /wiki/Ministry_of_Internal_Affairs_(Russia)
# /wiki/Sergei_Stepashin
# /wiki/Ivan_Goremykin
# /wiki/Pavel_Gagarin
# /wiki/Alexander_II_of_Russia
# /wiki/Sergei_Lvovich_Levitsky
# /wiki/Alexei_Nikolaevich,_Tsarevich_of_Russia
# /wiki/Grand_Duke_Vyacheslav_Konstantinovich_of_Russia
# /wiki/Russian_Empire
# /wiki/Boyar
# /wiki/Muslims
# /wiki/Animals_in_Islam
# /wiki/Islamic_hygienical_jurisprudence
# /wiki/Nikah_halala
# /wiki/Sunnah_prayer
# /wiki/Adab_(Islam)
# /wiki/Zina
# /wiki/Jihad
# /wiki/Taliban
# /wiki/Georgia_Train_and_Equip_Program
# /wiki/Al-Qaeda
# /wiki/Osama_bin_Laden
# /wiki/Embassy
# /wiki/Science_attach%C3%A9
# /wiki/Global_warming
# /wiki/World_energy_consumption
# /wiki/Electrical_energy
# /wiki/Dark_energy
# /wiki/DAMA/LIBRA
# /wiki/S2CID_(identifier)
# /wiki/Open_access_citation_advantage
# /wiki/Scientific_literature
# /wiki/Pamphlet
# /wiki/Poster_session
# /wiki/AMiner_(database)
# /wiki/CiteSeerX
# /wiki/Lee_Giles
# /wiki/Academic_genealogy
# /wiki/PhD
# /wiki/Doi_(identifier)
# /wiki/ISO_10628
# /wiki/ISO/IEC_27002
# /wiki/Shoe_size
# /wiki/Meta-Object_Facility
# /wiki/ISO_7200
# /wiki/PDF/VT
# /wiki/PDF/X
# /wiki/ISO_31-12
# /wiki/MP4_file_format
# /wiki/Multimedia
# /wiki/Telephone
# /wiki/Mobile_phone
# /wiki/Mobile_telephony
# /wiki/Wireless_service_provider
# /wiki/Tim_Berners-Lee
# /wiki/Yoshua_Bengio
# /wiki/Yann_LeCun
# /wiki/LaMDA
# /wiki/The_New_York_Times
# /wiki/Baltic_Fleet
# /wiki/Russian_Soviet_Federative_Socialist_Republic
# /wiki/War_of_Laws
# /wiki/Russian_language
# /wiki/Uzbek_language
# /wiki/Yei_Zhuang_language
# /wiki/Tungusic_languages
# /wiki/Na-Dene_languages
# /wiki/Hmong%E2%80%93Mien_languages
# /wiki/Kol_language_(Papua_New_Guinea)
# /wiki/Engan_languages
# /wiki/Hanseman_languages
# /wiki/Girawa_language
# /wiki/Pulabu_language
# /wiki/Mawak_language
# /wiki/Brahman_languages
# /wiki/Musak_language
# /wiki/Yangulam_language
# /wiki/Mosimo_language
# /wiki/Linkage_(linguistics)
# /wiki/Indonesia
# /wiki/Niue
# /wiki/India
# /wiki/World_Conservation_Union
# /wiki/Bruno_Oberle
# /wiki/Environmental_scientist
# /wiki/Outline_of_geography#Tasks_and_tools_of_geography
# /wiki/Nearctic
# /wiki/Bioregions
# /wiki/Global_200
# /wiki/Lesser_Sunda_Islands
# /wiki/West_Kalimantan
# /wiki/East_Kalimantan
# /wiki/Sangatta
# /wiki/UTC%2B8
# /wiki/Meridian_(geography)
# /wiki/Circle_of_latitude
# /wiki/5th_parallel_south
# /wiki/Equator
# /wiki/Tropic_of_Capricorn
# /wiki/Queensland
# /wiki/Chinatown,_Brisbane
# /wiki/Wickham_Park,_Brisbane
# /wiki/Brisbane_Airport
# /wiki/Ballina_Byron_Gateway_Airport
# /wiki/Busselton_Margaret_River_Airport
# /wiki/Moree_Airport
# /wiki/Chinchilla_Airport
# /wiki/Oakey_Army_Aviation_Centre
# /wiki/Sikorsky_S-70A-9_Black_Hawk
# /wiki/Sikorsky_S-61R
# /wiki/Pratt_%26_Whitney_F100
# /wiki/Fairchild_T46
# /wiki/Ranger_L-440
# /wiki/United_States_military_aircraft_engine_designations
# /wiki/Rolls-Royce_Turbomeca_Adour
# /wiki/Allison_J71
# /wiki/Rolls-Royce_AE_3007
# /wiki/Rolls-Royce_Trent_XWB
# /wiki/Turbofan
# /wiki/Engine_Alliance_GP7000
# /wiki/Engine_Alliance
# /wiki/GE_Industrial
# /wiki/S%26P_500
# /wiki/CNN
# /wiki/Just_for_Laughs_Radio
# /wiki/List_of_Sirius_XM_Radio_channels
# /wiki/Rihanna
# /wiki/Katy_Perry
# /wiki/GarageBand
# /wiki/John_Mayer
# /wiki/51st_Grammy_Awards
# /wiki/Grammy_Award_for_Best_Hawaiian_Music_Album
# /wiki/52nd_Annual_Grammy_Awards
# /wiki/Vickie_Winans
# /wiki/Shirley_Caesar
# /wiki/Mary_Mary
# /wiki/Platinum_certification
# /wiki/Gold_Record_(disambiguation)
# /wiki/Gold_record
# /wiki/Warner_Music_Group
# /wiki/Home_Box_Office
# /wiki/TT_Games
# /wiki/MCV_(magazine)
# /wiki/Gamasutra
# /wiki/Calgary_Expo
# /wiki/List_of_festivals_in_Prince_Edward_Island
# /wiki/History_of_Canada_(1960%E2%80%931981)
# /wiki/1839_in_Canada
# /wiki/1966_in_Canada
# /wiki/1726_in_Canada
# /wiki/2022_in_Canada
# /wiki/1724_in_Canada
# /wiki/1969_in_Canada
# /wiki/1816_in_Canada
# /wiki/2012_in_Canada
# /wiki/Japan
# /wiki/Jun%27ichir%C5%8D_Tanizaki
# /wiki/Ugetsu
# /wiki/California_Institute_of_Technology
# /wiki/University_of_California
# /wiki/University_of_California,_Los_Angeles
# /wiki/Los_Angeles_Dodgers
# /wiki/1965_World_Series
# /wiki/1976_in_baseball
# /wiki/New_York_Mets
# /wiki/East_Stroudsburg_Warriors
# /wiki/Seton_Hill_University#Athletics
# /wiki/NCAA_Division_II
# /wiki/ESPN
# /wiki/Andscape
# /wiki/Jemele_Hill
# /wiki/ESPN
# /wiki/ESPN_on_ABC
# /wiki/IROC_VII
# /wiki/Keke_Rosberg
# /wiki/1978_Dutch_Grand_Prix
# /wiki/Jean-Pierre_Jabouille
# /wiki/Renault_RE20
# /wiki/Renault_F1
# /wiki/Renault_R31
# /wiki/1997_Formula_One_World_Championship
# /wiki/2001_Formula_One_World_Championship
# /wiki/Michelin
# /wiki/Goodyear_Tire_and_Rubber_Company
# /wiki/Avery_Company
# /wiki/Automotive_industry
# /wiki/Film_industry
# /wiki/Health_insurance
# /wiki/Insurance_Regulatory_and_Development_Authority_of_India
# /wiki/Paytm_Payments_Bank
# /wiki/IDBI_Bank
# /wiki/Puduvai_Bharathiar_Grama_Bank
# /wiki/DBS_Bank
# /wiki/Chairman
# /wiki/Debate_(parliamentary_procedure)#Motion_to_limit_or_extend_limits_of_debate
# /wiki/Two-thirds_vote
# /wiki/Election
# /wiki/Oxford_University_Press
# /wiki/Mapledurham_House
# /wiki/Didcot_Railway_Centre
# /wiki/Museum_of_the_History_of_Science,_Oxford
# /wiki/Nobel_Prize
# /wiki/ISSN_(identifier)
# /wiki/ISO_8000
# /wiki/ISO/IEC_14651
# /wiki/X.500
# /wiki/Graphical_Kernel_System
# /wiki/File_Allocation_Table
# /wiki/Computer_program
# /wiki/Capacitor
# /wiki/Second_World_War
# /wiki/Potsdam_Declaration
# /wiki/Prague_offensive
# /wiki/Oberkommando_der_Wehrmacht
# /wiki/Command_(military_formation)
# /wiki/Commissioned_officer
# /wiki/Reconnaissance_aircraft
# /wiki/Observation_seaplane
# /wiki/Curtiss_Aeroplane_and_Motor_Company
# /wiki/Curtiss_XP-31_Swift
# /wiki/Curtiss_Falcon
# /wiki/Vought
# /wiki/F-22_Raptor
# /wiki/Lockheed_Senior_Prom
# /wiki/RIM-113
# /wiki/Nord_CT41
# /wiki/Ryan_Firebee
# /wiki/FIM-92_Stinger
# /wiki/2020_Balyun_airstrikes
# /wiki/Aleppo_offensive_(October%E2%80%93December_2015)
# /wiki/Facebook
# /wiki/Meta_Portal
# /wiki/Sonos_One
# /wiki/Tweeter
# /wiki/Super_tweeter
# /wiki/Loudspeaker
# /wiki/Tweeter
# /wiki/Tweeter_(store)
# /wiki/Emergency_Economic_Stabilization_Act_of_2008
# /wiki/Citigroup
# /wiki/Foreign_exchange_market
# /wiki/Financial_institution
# /wiki/Financial_technology
# /wiki/ISBN_(identifier)
# /wiki/ISO_19092-1
# /wiki/Office_Open_XML
# /wiki/NeoOffice
# /wiki/Office_suite
# /wiki/Zoho_Office_Suite
# /wiki/Free_and_open-source_software
# /wiki/Ecuador
# /wiki/Gal%C3%A1pagos_Islands
# /wiki/Sierra_Negra_(Gal%C3%A1pagos)
# /wiki/Isla_Guy_Fawkes
# /wiki/William_Beebe
# /wiki/SS_Egypt
# /wiki/Scuba_Educators_International
# /wiki/Konsul-class_submersible
# /wiki/Science_of_underwater_diving
# /wiki/Zale_Parry
# /wiki/Immersion_finswimming
# /wiki/Dive_leader
# /wiki/Suunto
# /wiki/James_Talacek
# /wiki/Barodontalgia
# /wiki/Michele_Westmorland
# /wiki/Josef_Velek
# /wiki/Checklist
# /wiki/David_Saint-Jacques
# /wiki/Reclaim_helmet
# /wiki/Rescue_Diver
# /wiki/Royal_Australian_Navy_School_of_Underwater_Medicine
# /wiki/Decompression_practice
# /wiki/Fuerzas_Especiales
# /wiki/Special_operations
# /wiki/Police_Tactical_Unit
# /wiki/Doi_(identifier)
# /wiki/ISBN
# /wiki/ISO/IEC_7816
# /wiki/ISO/IEC_27000-series
# /wiki/ISO_22000
# /wiki/ISO_3166-2
# /wiki/Departments_of_Haiti
# /wiki/Chambellan
# /wiki/Granger,_Grand%27Anse
# /wiki/Geographic_coordinate_system
# /wiki/IERS_Reference_Meridian
# /wiki/Western_Hemisphere
# /wiki/France
# /wiki/Battle_of_Austerlitz
# /wiki/Battle_of_Pu%C5%82tusk_(1806)
# /wiki/Frederick_VI_of_Denmark
# /wiki/Haakon_VI_of_Norway
# /wiki/Sten_Sture_the_Younger
# /wiki/Charles_X_Gustav_of_Sweden
# /wiki/H%C3%A5kan_the_Red
# /wiki/House_of_Griffins
# /wiki/Bogus%C5%82aw_I,_Duke_of_Pomerania
# /wiki/Wartislaw_I,_Duke_of_Pomerania
# /wiki/Casimir_I,_Duke_of_Pomerania
# /wiki/Wartislaw_II,_Duke_of_Pomerania
# /wiki/Casimir_II,_Duke_of_Pomerania
# /wiki/Denmark
# /wiki/List_of_extreme_points_of_Denmark
# /wiki/Aarhus_County
# /wiki/N%C3%B8rre_Djurs_municipality
# /wiki/Region_Midtjylland
# /wiki/Himmelbjerget
# /wiki/Ejer_Bavneh%C3%B8j
# /wiki/Yding_Skovh%C3%B8j
# /wiki/Burial_mounds
# /wiki/Bronze_Age
# /wiki/Dover_Bronze_Age_Boat
# /wiki/Lagaren
# /wiki/United_States_lightship_Ambrose_(LV-87)
# /wiki/National_Register_of_Historic_Places_listings_in_St._Lawrence_County,_New_York
# /wiki/Ogdensburg,_New_York
# /wiki/Massena,_New_York
# /wiki/Administrative_divisions_of_New_York#Village
# /wiki/Brooklyn
# /wiki/Newark_Liberty_International_Airport
# /wiki/Paul_Mijksenaar
# /wiki/New_York_City
# /wiki/Herkimer_(town),_New_York
# /wiki/Plattekill_(town),_New_York
# /wiki/Notch_Lake
# /wiki/Muscoot_Reservoir
# /wiki/Delaware_River
# /wiki/Pennypack_Creek
# /wiki/Fetter%27s_Mill
# /wiki/National_Register_of_Historic_Places_listings_in_Venango_County,_Pennsylvania
# /wiki/National_Register_of_Historic_Places_listings_in_Pittsburgh,_Pennsylvania
# /wiki/McCook_Family_Estate
# /wiki/National_Register_of_Historic_Places_listings_in_Wyoming_County,_Pennsylvania
# /wiki/Tunkhannock_Township,_Wyoming_County,_Pennsylvania
# /wiki/Daylight_saving_time
# /wiki/Scandinavia
# /wiki/Norwegian_language
# /wiki/Danish_dialects
# /wiki/West_Frisian_language
# /wiki/Arabic
# /wiki/Post-industrial_society
# /wiki/Society#Types
# /wiki/Industrial_society
# /wiki/Industrial_Revolution
# /wiki/Cold_War
# /wiki/Non-Aligned_Movement
# /wiki/Timothy_Garton_Ash
# /wiki/Georgian%E2%80%93Ossetian_conflict
# /wiki/Politics_of_Georgia_(country)
# /wiki/Irina_Sarishvili-Chanturia
# /wiki/Eduard_Shevardnadze
# /wiki/Komsomol
# /wiki/Leonid_Brezhnev
# /wiki/Communist_Party_of_Moldavia#First_Secretaries
# /wiki/Ban_on_factions_in_the_Communist_Party_of_the_Soviet_Union
# /wiki/Central_Committee_of_the_1st_Conference_of_the_Russian_Social_Democratic_Labour_Party
# /wiki/Tampere_conference_of_1905
# /wiki/Central_Auditing_Commission_of_the_16th_Congress_of_the_All-Union_Communist_Party_(Bolsheviks)
# /wiki/Central_Committee_of_the_2nd_Congress_of_the_Russian_Social_Democratic_Labour_Party
# /wiki/Communist_Party_of_Bukhara
# /wiki/Inner-composition_of_the_6th_Congress_of_the_Russian_Social_Democratic_Labour_Party_(Bolsheviks)
# /wiki/19th_Conference_of_the_Communist_Party_of_the_Soviet_Union
# /wiki/Congress_of_People%27s_Deputies_of_the_Soviet_Union
# /wiki/History_of_the_Soviet_Union
# /wiki/Peaceful_coexistence
# /wiki/Reykjav%C3%ADk_Summit
# /wiki/Nuclear_arms_race
# /wiki/Mongolian_Revolution_of_1990
# /wiki/Bangladesh_Liberation_War
# /wiki/ISBN_(identifier)
# /wiki/ISO_26000
# /wiki/ISO_216
# /wiki/ISO_13567
# /wiki/ISO_5427
# /wiki/ISO_11940-2
# /wiki/Cloud_Infrastructure_Management_Interface
# /wiki/ISO_13406-2
# /wiki/110_film
# /wiki/Legal_Entity_Identifier
# /wiki/ISO/IEC_8859-13
# /wiki/ANSI_escape_code
# /wiki/ISO/IEC_19770
# /wiki/ANSI_C
# /wiki/IEC_62325
# /wiki/IEC_62264
# /wiki/MPEG-A
# /wiki/ISO/IEC_29119
# /wiki/ISO_15926
# /wiki/Upstream_(oil_industry)
# /wiki/OPEC
# /wiki/Kharkiv_Pact
# /wiki/Andriy_Parubiy
# /wiki/Ukrinform
# /wiki/News_Agency_of_the_Slovak_Republic
# /wiki/Prague
# /wiki/Civic_Democratic_Party_(Czech_Republic)
# /wiki/Mayors_and_Independents
# /wiki/National_Democracy_(Czech_Republic)
# /wiki/Civic_Conservative_Party_(Czech_Republic)
# /wiki/KDU-%C4%8CSL
# /wiki/Jaroslava_Moserov%C3%A1
# /wiki/Martin_Pot%C5%AF%C4%8Dek
# /wiki/Czech_Republic
# /wiki/Brno%E2%80%93Tu%C5%99any_Airport
# /wiki/Brno_Exhibition_Centre
# /wiki/Central_Europe
# /wiki/Media_freedom_in_the_European_Union
# /wiki/European_Union_legislative_procedure
# /wiki/Copyright_Duration_Directive
# /wiki/Sweden
# /wiki/Union_between_Sweden_and_Norway
# /wiki/Russian_Empire
# /wiki/Caucasian_War
# /wiki/Sochi_conflict
# /wiki/Russia
# /wiki/The_World_Factbook
# /wiki/Encyclopedia_of_the_Central_Intelligence_Agency
# /wiki/1953_Iranian_coup_d%27%C3%A9tat
# /wiki/Geneva_Summit_(1985)
# /wiki/Jack_Reagan
# /wiki/Tax_Reform_Act_of_1986
# /wiki/There_you_go_again
# /wiki/Attempted_assassination_of_Ronald_Reagan
# /wiki/Homicide
# /wiki/Angel_of_mercy_(criminology)
# /wiki/Lust_murder
# /wiki/Algolagnia
# /wiki/Acrotomophilia
# /wiki/Transvestic_fetishism
# /wiki/Lust_murder
# /wiki/Doi_(identifier)
# /wiki/On-board_diagnostics
# /wiki/Data_link_connector_(automotive)
# /wiki/Scan_tool_(automotive)
# /wiki/Data_link_connector_(automotive)
# /wiki/Diagnostic
# /wiki/Analytics
# /wiki/Analysis
# /wiki/Metabolism
# /wiki/HMG-CoA_synthase
# /wiki/List_of_enzymes
# /wiki/Nitrogen
# /wiki/Functional_group
# /wiki/Carbonate_ester
# /wiki/Solvents
# /wiki/Diethyl_ether
# /wiki/National_Institute_for_Occupational_Safety_and_Health
# /wiki/Office_of_the_National_Coordinator_for_Health_Information_Technology
# /wiki/HITECH_Act
# /wiki/Electronic_health_records_in_the_United_States
# /wiki/American_Recovery_and_Reinvestment_Act_of_2009
# /wiki/Democratic_National_Committee
# /wiki/Party_platform
# /wiki/Divided_government
# /wiki/Consensus_government
# /wiki/Politics_of_Fiji
# /wiki/Sport_in_Fiji
# /wiki/Climate_change_in_Fiji
# /wiki/Climate_change_in_the_Marshall_Islands
# /wiki/Ailinginae_Atoll
# /wiki/Ebon_Atoll
# /wiki/Namdrik_Atoll
# /wiki/Jaluit_High_School
# /wiki/Public_holidays_in_the_Marshall_Islands
# /wiki/Public_holidays_in_Samoa
# /wiki/New_Year%27s_Day
# /wiki/Public_holidays_in_Tonga
# /wiki/Lapita_culture
# /wiki/Languages_of_French_Polynesia
# /wiki/English_language
# /wiki/Niue
# /wiki/Asian_American_and_Pacific_Islander_Policy_Research_Consortium
# /wiki/Australian_Institute_of_Aboriginal_and_Torres_Strait_Islander_Studies
# /wiki/Cockington_Green_Gardens
# /wiki/National_Carillon
# /wiki/Lake_Burley_Griffin
# /wiki/Yarramundi_Reach
# /wiki/Australian_Capital_Territory
# /wiki/Pre-School
# /wiki/Democratic_education
# /wiki/School_district_drug_policies
# /wiki/Wayback_Machine
# /wiki/Digital_curation
# /wiki/OCLC_(identifier)
# /wiki/Doing_business_as
# /wiki/California
# /wiki/Peoples_of_Palawan
# /wiki/Maranao_people
# /wiki/Ramayana
# /wiki/Mahakali
# /wiki/Sita_Upanishad
# /wiki/Upaveda
# /wiki/Brahmanda_Purana
# /wiki/Shiva_Swarodaya
# /wiki/Chinese_Esoteric_Buddhism
# /wiki/Homa_(ritual)
# /wiki/Mahavidya
# /wiki/Six_Dharmas_of_Naropa
# /wiki/ISBN_(identifier)
# /wiki/ISO_5428
# /wiki/MP4_file_format
# /wiki/Smartphones
# /wiki/History_of_telecommunication
# /wiki/Hydraulic_telegraph#Greek_hydraulic_semaphore_system
# /wiki/Thessaloniki_Science_Center_and_Technology_Museum
# /wiki/Pammegistoi_Taxiarches_church
# /wiki/Presentation_of_the_Virgin_Mary_Cathedral,_Chania
# /wiki/Peloponnese
# /wiki/Patras
# /wiki/Icon
# /wiki/Icon_corner
# /wiki/Holy_water#Eastern_Orthodox_holy_water
# /wiki/Halalta
# /wiki/Scroll_of_Exalted_Kingship
# /wiki/Anush_(Mandaeism)
# /wiki/Recording_angel
# /wiki/Saureil
# /wiki/Angels_in_art
# /wiki/Seraphim
# /wiki/Tell_Halaf
# /wiki/Quw%C3%AA
# /wiki/Ancient_regions_of_Anatolia
# /wiki/Pontus_(region)
# /wiki/Argonauts
# /wiki/Ancient_Greek
# /wiki/Ancient_Macedonian_language
# /wiki/Extinct_language
# /wiki/Sab%C3%BCm
# /wiki/Lavi_language
# /wiki/Waic_languages
# /wiki/Katua_language
# /wiki/Gelao_language
# /wiki/Ho%C3%A0ng_Su_Ph%C3%AC
# /wiki/Na_R%C3%AC_district
# /wiki/C%C3%B4n_Minh
# /wiki/Qu%E1%BA%A3ng_Kh%C3%AA,_B%E1%BA%AFc_K%E1%BA%A1n
# /wiki/Hi%E1%BB%87p_L%E1%BB%B1c,_B%E1%BA%AFc_K%E1%BA%A1n
# /wiki/Qu%E1%BA%A3ng_Chu
# /wiki/Li%C3%AAm_Th%E1%BB%A7y
# /wiki/B%E1%BA%B1ng_Ph%C3%BAc
# /wiki/Nghi%C3%AAn_Loan
# /wiki/Nguy%E1%BB%85n_Th%E1%BB%8B_Minh_Khai,_B%E1%BA%AFc_K%E1%BA%A1n
# /wiki/Qu%E1%BA%A3ng_Kh%C3%AA,_B%E1%BA%AFc_K%E1%BA%A1n
# /wiki/H%C3%B2a_M%E1%BB%A5c
# /wiki/B%E1%BA%B1ng_Th%C3%A0nh
# /wiki/Nh%C6%B0_C%E1%BB%91
# /wiki/D%C6%B0%C6%A1ng_Quang,_B%E1%BA%AFc_K%E1%BA%A1n
# /wiki/Hi%E1%BB%87p_L%E1%BB%B1c,_B%E1%BA%AFc_K%E1%BA%A1n
# /wiki/Y%C3%AAn_H%C3%A2n
# /wiki/Thanh_V%E1%BA%ADn
# /wiki/Thu%E1%BA%A7n_Mang
# /wiki/B%E1%BA%AFc_K%E1%BA%A1n_province
# /wiki/Indochina_Time
# /wiki/Bogor
# /wiki/Surakarta
# /wiki/Tegal_Regency
# /wiki/Indonesia
# /wiki/List_of_states_with_limited_recognition
# /wiki/Political_status_of_Taiwan
# /wiki/Taiwan_Affairs_Office
# /wiki/Tibet_Religious_Foundation_of_His_Holiness_the_Dalai_Lama
# /wiki/Chinese_intelligence_activity_abroad
# /wiki/Four_Noes_and_One_Without
# /wiki/Politics_of_Hainan
# /wiki/State_Council_of_the_People%27s_Republic_of_China
# /wiki/Cabinet_of_Macau
# /wiki/Cabinet_of_India
# /wiki/Ministry_of_Electronics_and_Information_Technology
# /wiki/Jagjivan_Ram
# /wiki/Bansi_Lal
# /wiki/Swang_(dance_drama)
# /wiki/Tertali
# /wiki/Mayilattam
# /wiki/Kathak
# /wiki/Ramcharitmanas
# /wiki/Shiva_Dhanush
# /wiki/Niyama
# /wiki/Bodhipakkhiy%C4%81dhamm%C4%81
# /wiki/Buddhist_socialism
# /wiki/Colin_Ward
# /wiki/Pierre-Joseph_Proudhon
# /wiki/Magonism
# /wiki/Agorism
# /wiki/Abolitionism
# /wiki/John_Gregg_Fee
# /wiki/Cassius_Marcellus_Clay_(abolitionist)
# /wiki/American_Civil_War
# /wiki/2020%E2%80%932023_United_States_racial_unrest
# /wiki/Audiobook
# /wiki/Book_swapping
# /wiki/Platform_economy
# /wiki/PickMe
# /wiki/Crowdfunding
# /wiki/Yandex.Taxi
# /wiki/Yandex.Navigator
# /wiki/Yandex_Launcher
# /wiki/GUI
# /wiki/Gamasutra
# /wiki/Fan_Expo
# /wiki/Monaco_Yacht_Show
# /wiki/Game_Developers_Conference
# /wiki/San_Francisco
# /wiki/List_of_parks_in_San_Francisco
# /wiki/Corona_Heights_Park
# /wiki/List_of_diplomatic_missions_in_San_Francisco
# /wiki/Embassy_of_the_United_Kingdom,_Washington,_D.C.
# /wiki/Embassy_of_Bosnia_and_Herzegovina,_Washington,_D.C.
# /wiki/Tuzla
# /wiki/Kalesija
# /wiki/Republika_Srpska
# /wiki/Gregorian_calendar
# /wiki/Buddhist_calendar
# /wiki/Enlightenment_in_Buddhism
# /wiki/Buddhism_in_Japan
# /wiki/Pure_Land
# /wiki/%C4%80nanda
# /wiki/Kushinagar
# /wiki/Pratimok%E1%B9%A3a
# /wiki/Ten_realms
# /wiki/P%C4%81li_Canon
# /wiki/Buddhism_in_the_West
# /wiki/Shohaku_Okumura
# /wiki/Huayan
# /wiki/Sangha
# /wiki/Glossary_of_Buddhism
# /wiki/Sangha_(Buddhism)
# /wiki/Assaji
# /wiki/Ajahn
# /wiki/Samantabhadra_Bodhisattva
# /wiki/Pabongkhapa_D%C3%A9chen_Nyingpo
# /wiki/ISBN_(identifier)
# /wiki/Film_speed
# /wiki/ISO_31-7
# /wiki/ISO/IEC_11801
# /wiki/ARJ45
# /wiki/ISO/IEC_11801#Category_8
# /wiki/Twisted-pair
# /wiki/ISBN_(identifier)
# /wiki/ISO_1629
# /wiki/ISO_128
# /wiki/ISO_216
# /wiki/ISO/IEC_7810
# /wiki/Digital_Addressable_Lighting_Interface
# /wiki/FlexRay
# /wiki/Megabit
# /wiki/Orders_of_magnitude_(data)
# /wiki/Orders_of_magnitude_(power)
# /wiki/Laboratory_for_Laser_Energetics
# /wiki/HiPER
# /wiki/IGNITOR
# /wiki/Tokamak
# /wiki/Nuclear_power_plant
# /wiki/Generation_IV_reactor
# /wiki/TerraPower
# /wiki/Bill_Gates#Recognition
# /wiki/Mahatma_Gandhi
# /wiki/Elizabeth_II
# /wiki/Australian_Senate
# /wiki/Ralph_Babet
# /wiki/Bachelor_of_Business
# /wiki/Curtin_University_of_Technology
# /wiki/Ben_Templesmith
# /wiki/List_of_Greyhawk_deities
# /wiki/Kara-Tur
# /wiki/Xenophobic
# /wiki/Nationalism_studies
# /wiki/Irredentism
# /wiki/Non-state_actor
# /wiki/Cotonou_Agreement
# /wiki/International_Criminal_Court
# /wiki/SSRN_(identifier)
# /wiki/Dead_link
# /wiki/CiteSeerX_(identifier)
# /wiki/Lucene
# /wiki/Chainsaw_(log_file_viewer)
# /wiki/Apache_iBATIS
# /wiki/Apache_FOP_(Formatting_Objects_Processor)
# /wiki/Apache_Batik
# /wiki/Apache_Pig
# /wiki/NuttX
# /wiki/MachTen
# /wiki/Cygwin
# /wiki/Unix
# /wiki/Awk
# /wiki/Find_(Unix)
# /wiki/Version_5_Unix
# /wiki/Curses_(programming_library)
# /wiki/Rogue_(computer_game)
# /wiki/ISBN_(identifier)
# /wiki/PDF/X
# /wiki/ISO/IEC_8859-2
# /wiki/Windows-1254
# /wiki/UTF-16
# /wiki/Ge%CA%BDez_script
# /wiki/Greek_numerals
# /wiki/Sphaerics
# /wiki/Thales%27s_theorem
# /wiki/Dionysodorus
# /wiki/Law_of_cosines
# /wiki/Triangle#Types_of_triangle
# /wiki/Orthodiagonal_quadrilateral
# /wiki/The_Mathematical_Gazette
# /wiki/National_Numeracy_Strategy
# /wiki/Mathematics_in_Education_and_Industry
# /wiki/National_Numeracy
# /wiki/Edinburgh_Mathematical_Society
# /wiki/Millennium_Mathematics_Project
# /wiki/Thomas_Bond_Sprague_Prize
# /wiki/Footlights
# /wiki/Cambridge
# /wiki/St_Ives,_Cambridgeshire
# /wiki/Conservative_Party_(UK)
# /wiki/1979_United_Kingdom_general_election
# /wiki/Jim_Sillars
# /wiki/Douglas_Chapman_(Scottish_politician)
# /wiki/Member_of_Parliament_(United_Kingdom)
# /wiki/Dominic_Raab
# /wiki/Brexit_divorce_bill
# /wiki/BBC_News
# /wiki/Selina_Scott
# /wiki/Area_of_Outstanding_Natural_Beauty
# /wiki/National_scenic_area_(Scotland)
# /wiki/Isle_of_Arran
# /wiki/Catacol
# /wiki/Scottish_Gaelic_language
# /wiki/Nova_Scotia
# /wiki/Quebec
# /wiki/ISBN_(identifier)
# /wiki/Legal_Entity_Identifier
# /wiki/Meta-Object_Facility
# /wiki/ISO_31-10
# /wiki/Knowledge_Discovery_Metamodel
# /wiki/ISO/IEC_9529
# /wiki/ISO/IEC_8859-5
# /wiki/KOI8-T
# /wiki/Q
# /wiki/Block_letters
# /wiki/Wayback_Machine
# /wiki/Internet_censorship_in_Bahrain
# /wiki/Telecommunications_in_Honduras#Internet_censorship_and_surveillance
# /wiki/Telecommunications_in_Namibia#Internet_censorship_and_surveillance
# /wiki/Jun-ichi_Nishizawa
# /wiki/Tohoku_University
# /wiki/%C3%89cole_nationale_sup%C3%A9rieure_des_mines_de_Paris
# /wiki/Groupe_des_%C3%A9coles_nationales_d%E2%80%99ing%C3%A9nieurs
# /wiki/%C3%89cole_nationale_sup%C3%A9rieure_d%27informatique_pour_l%27industrie_et_l%27entreprise
# /wiki/ESIEA_(university)
# /wiki/EDC_Paris_Business_School
# /wiki/%C3%89cole_des_ponts_ParisTech
# /wiki/Ch%C3%A2teau_de_Champs-sur-Marne
# /wiki/Guermantes
# /wiki/L%C3%A9signy,_Seine-et-Marne
# /wiki/Vaudoy-en-Brie
# /wiki/Vaires-sur-Marne
# /wiki/Oberschlei%C3%9Fheim_Regatta_Course
# /wiki/Rowing_at_the_1924_Summer_Olympics
# /wiki/Robert_Hunter_(rower)
# /wiki/1924_Summer_Olympics
# /wiki/1960_Summer_Olympics
# /wiki/1992_Summer_Olympics
# /wiki/Colonialism_and_the_Olympic_Games
# /wiki/1972_Summer_Olympics
# /wiki/Water_skiing_at_the_1972_Summer_Olympics
# /wiki/Italy_at_the_1972_Summer_Olympics
# /wiki/Novella_Calligaris
# /wiki/East_Germany
# /wiki/ISBN_(identifier)
# /wiki/Computer_Graphics_Metafile
# /wiki/Pascal_(programming_language)
# /wiki/Assembly_language
# /wiki/David_John_Wheeler
# /wiki/ISBN_(identifier)
# /wiki/ISO_15926
# /wiki/Requirements_engineering
# /wiki/ISO_31
# /wiki/ISO_14971
# /wiki/MP4_file_format
# /wiki/ISO_4
# /wiki/List_of_IEC_standards
# /wiki/Lexical_Markup_Framework
# /wiki/Flowchart
# /wiki/Allan_H._Mogensen
# /wiki/Cornell_University
# /wiki/Archaeological_excavation
# /wiki/Dumpy_level
# /wiki/Water_level_(device)
# /wiki/Hanley_Wood
# /wiki/MidOcean_Partners
# /wiki/Institutional_investor
# /wiki/List_of_institutional_investors_in_the_United_Kingdom
# /wiki/List_of_trade_unions_in_the_United_States
# /wiki/Communications_Workers_of_America
# /wiki/Unfair_labor_practice
# /wiki/United_States_labor_law
# /wiki/Eight-hour_day#United_States
# /wiki/Labour_Party_(Ireland)
# /wiki/2002_Irish_general_election
# /wiki/Sinn_F%C3%A9in
# /wiki/2018_Irish_presidential_election
# /wiki/1944_Irish_general_election
# /wiki/1965_Irish_general_election
# /wiki/Joseph_Blowick
# /wiki/John_A._Costello
# /wiki/Taoiseach
# /wiki/September_1927_Irish_general_election
# /wiki/Irish_Statute_Book
# /wiki/Attorney_General_of_Ireland
# /wiki/Department_of_State_(Ireland)
# /wiki/List_of_D%C3%A1il_by-elections
# /wiki/National_University_of_Ireland_(constituency)
# /wiki/1948_Irish_general_election
# /wiki/T%C3%A1naiste
# /wiki/Garret_FitzGerald
# /wiki/Mark_Killilea_Snr
# /wiki/Seanad_%C3%89ireann
# /wiki/D%C3%A1il_constituencies
# /wiki/Currency_Centre
# /wiki/Republic_of_Ireland
# /wiki/Irish_music
# /wiki/Act_for_the_Settlement_of_Ireland_1652
# /wiki/Coming_into_force
# /wiki/Act_of_Congress
# /wiki/House_Democratic_Caucus
# /wiki/United_States_Capitol_cornerstone_laying
# /wiki/Society_of_the_Cincinnati
# /wiki/James_Clinton
# /wiki/The_Pioneers_(novel)
# /wiki/Paperback
# /wiki/Book_review
# /wiki/Publishing
# /wiki/Wayback_Machine
# /wiki/Sloan_Foundation
# /wiki/Alfred_P._Sloan_Jr.
# /wiki/General_Motors_Canada
# /wiki/Geo_Metro
# /wiki/Chevrolet_Superior
# /wiki/Chevrolet_Camaro_(fifth_generation)#Camaro_SSX_(2010)
# /wiki/SangYup_Lee
# /wiki/YouTube
# /wiki/Google_barges
# /wiki/Censorship_by_Google#YouTube
# /wiki/Don%27t_be_evil
# /wiki/Google_Mashup_Editor
# /wiki/The_Internship
# /wiki/The_Onion
# /wiki/KOMR
# /wiki/KLNZ
# /wiki/Jazz
# /wiki/Mulatto
# /wiki/ISBN_(identifier)
# /wiki/TIFF/EP
# /wiki/IGES
# /wiki/ILBM
# /wiki/JPEG_Network_Graphics
# /wiki/Unified_Speech_and_Audio_Coding
# /wiki/G.729
# /wiki/Frame_(telecommunication)
# /wiki/High-Level_Data_Link_Control#Asynchronous_framing
# /wiki/Point-to-point_(telecommunications)
# /wiki/Circuit_switching
# /wiki/Telephone_call
# /wiki/Fax
# /wiki/Pantelegraph
# /wiki/French_Academy_of_Sciences
# /wiki/Jean-Baptiste_Colbert
# /wiki/Jules_de_Cl%C3%A9rambault
# /wiki/Jean_de_La_Fontaine
# /wiki/5780_Lafontaine
# /wiki/Carolyn_S._Shoemaker
# /wiki/30785_Greeley
# /wiki/Takeshi_Urata
# /wiki/Minor_planet
# /wiki/3_Juno
# /wiki/Opposition_(astronomy)
# /wiki/Phase_angle_(astronomy)
# /wiki/Mars
# /wiki/Mars_1
# /wiki/Mars_Orbiter_Mission
# /wiki/Escape_velocity
# /wiki/Parabola
# /wiki/ArXiv_(identifier)
# /wiki/Charles_F._Berman_Field
# /wiki/Diacritics_(journal)
# /wiki/Sage_Hall
# /wiki/Cornell_University_Chorus
# /wiki/Cornell_Policy_Review
# /wiki/Telluride_House
# /wiki/Morrill_Land_Grant_Act_of_1862
# /wiki/Public_Law_(United_States)
# /wiki/House_Page_Board
# /wiki/Plural_district
# /wiki/Salaries_of_members_of_the_United_States_Congress
# /wiki/Congressional_office_buildings
# /wiki/Westward_the_Course_of_Empire_Takes_Its_Way
# /wiki/Emanuel_Leutze
# /wiki/Joseph_Anton_Koch
# /wiki/Ossian
# /wiki/Nikolay_Karamzin
# /wiki/Conservatism_in_Germany
# /wiki/Conservatism#Italy
# /wiki/Secretary_(title)
# /wiki/First_Secretary_of_State
# /wiki/Michael_Stewart,_Baron_Stewart_of_Fulham
# /wiki/Bromley
# /wiki/Hanwell
# /wiki/East_Acton
# /wiki/List_of_districts_in_the_London_Borough_of_Harrow
# /wiki/Pinner
# /wiki/Harrow_Skate_Park
# /wiki/Half-pipe
# /wiki/Cross-country_skiing_trail
# /wiki/Temperature_gradient
# /wiki/Weathering#Thermal_stress
# /wiki/Erosion
# /wiki/Vortex
# /wiki/LCCN_(identifier)
# /wiki/Hyphen
# /wiki/Cascading_Style_Sheets
# /wiki/SVG_Working_Group
# /wiki/Sun_Microsystems
# /wiki/James_L._Barksdale
# /wiki/Jackson,_Mississippi
# /wiki/Brookhaven,_Mississippi
# /wiki/Federal_Information_Processing_Standard
# /wiki/Geodesic
# /wiki/Riemannian_manifold
# /wiki/Vector_bundle
# /wiki/Integral_curve
# /wiki/Almost_symplectic_manifold
# /wiki/Jet_bundle
# /wiki/Pseudo-Riemannian_manifold
# /wiki/Connection_form
# /wiki/Rizza_manifold
# /wiki/Shoshichi_Kobayashi
# /wiki/Almost-complex_structure
# /wiki/Connection_(fibred_manifold)
# /wiki/Stratified_space
# /wiki/Thom%E2%80%93Mather_stratified_space
# /wiki/Hausdorff_space
# /wiki/Filter_(topology)
# /wiki/Fr%C3%A9chet%E2%80%93Urysohn_space
# /wiki/Barrelled_space
# /wiki/Lecture_Notes_in_Mathematics
# /wiki/Miriam_Balaban
# /wiki/Frank_Kreith
# /wiki/Robert_N._Noyce
# /wiki/I/O_Acceleration_Technology
# /wiki/P6_(microarchitecture)
# /wiki/Streaming_SIMD_Extensions
# /wiki/MMX_(instruction_set)
# /wiki/Intel
# /wiki/TSMC
# /wiki/Samsung_Electronics
# /wiki/Tokyo_Electron
# /wiki/Japan
# /wiki/OpenStreetMap
# /wiki/Forbes
# /wiki/Elevation_Partners
# /wiki/Electronic_Arts
# /wiki/Copart
# /wiki/Rivian
# /wiki/General_Motors
# /wiki/BrightDrop
# /wiki/Renaissance_Center
# /wiki/Kentucky
# /wiki/President_of_the_Senate
# /wiki/President_of_the_Chamber_of_Representatives_of_Colombia
# /wiki/2010_Colombian_presidential_election
# /wiki/President_of_Colombia
# /wiki/Mineral_industry_of_Colombia
# /wiki/List_of_sovereign_states
# /wiki/United_States_Virgin_Islands
# /wiki/Territorial_dispute
# /wiki/Asymmetric_federalism
# /wiki/Federal_subjects_of_Russia#Types
# /wiki/States_and_federal_territories_of_Malaysia
# /wiki/Abdullah_of_Pahang
# /wiki/Abdul_Taib_Mahmud
# /wiki/2011_Sarawak_state_election
# /wiki/2013_Malaysian_general_election
# /wiki/People%27s_Progressive_Party_(Malaysia)
# /wiki/List_of_political_parties_in_Malaysia
# /wiki/Malaysia_National_Alliance_Party
# /wiki/United_Democratic_Sabah_People%27s_Power_Party
# /wiki/Malaysian_Indian_Muslim_Congress
# /wiki/Gabungan_Rakyat_Sabah
# /wiki/Joachim_Gunsalam
# /wiki/Sabah_United_Party
# /wiki/Bumiputera_(Malaysia)
# /wiki/Disabilities_(Catholics)
# /wiki/Discrimination_against_intersex_people
# /wiki/Social_exclusion
# /wiki/Slut-shaming
# /wiki/Persecution_of_Hazaras
# /wiki/Discrimination_in_education
# /wiki/Disabilities_(Jewish)
# /wiki/Age_segregation
# /wiki/Religious_war
# /wiki/Defeat_in_detail
# /wiki/Military_rank
# /wiki/Military_ranks_of_South_Sudan
# /wiki/Comparative_air_force_enlisted_ranks_of_Asia
# /wiki/Sergeant
# /wiki/United_States_Marine_Corps_Aviation#Squadrons
# /wiki/Close_air_support
# /wiki/Airpower
# /wiki/F-22_Raptor
# /wiki/Relaxed_stability
# /wiki/1903_Wright_Flyer
# /wiki/Sprocket
# /wiki/Luggage_carrier
# /wiki/Utility_bicycle
# /wiki/Bottle_dynamo
# /wiki/Dynamo
# /wiki/Power_semiconductor_device
# /wiki/Semiconductor_device
# /wiki/University_of_Chicago
# /wiki/Day_school
# /wiki/College
# /wiki/TAFE
# /wiki/University_of_Ballarat
# /wiki/Monash_University
# /wiki/Education_in_Australia
# /wiki/Queensland_Certificate_of_Education
# /wiki/Australian_Qualifications_Framework#Certificates_I-IV
# /wiki/Recognition_of_Prior_Learning
# /wiki/SS_Commodore
# /wiki/Muscle_memory
# /wiki/Dancing
# /wiki/Popping_(dance)
# /wiki/Flexing_(dance)
# /wiki/Tap_dance
# /wiki/Peruvian_dances
# /wiki/Erotic_dance
# /wiki/Assyrian_folk_dance
# /wiki/Neo-Assyrian_Empire
# /wiki/ISBN_(identifier)
# /wiki/ISO_19092-2
# /wiki/ISO_3166
# /wiki/Geohash-36
# /wiki/Marsden_square
# /wiki/Postcodes_in_Australia
# /wiki/Optical_character_recognition
# /wiki/Coreference#Coreference_resolution
# /wiki/Quantificational_variability_effect
# /wiki/Anaphora_(linguistics)
# /wiki/Quantization_(linguistics)
# /wiki/Speech_act
# /wiki/Semantic_externalism
# /wiki/Contextualism
# /wiki/LGBT_linguistics
# /wiki/Kira_Hall
# /wiki/Mary_Bucholtz
# /wiki/S2CID_(identifier)
# /wiki/Scopus
# /wiki/PMC_(identifier)
# /wiki/Scientific_writing
# /wiki/Patent
# /wiki/Doi_(identifier)
# /wiki/ISO/IEC_15897
# /wiki/ISO_metric_screw_thread
# /wiki/Renard_series
# /wiki/JBIG
# /wiki/Photographic_Activity_Test
# /wiki/ISO_11784_and_ISO_11785
# /wiki/Microchip_implant_(animal)
# /wiki/ISO_11784_and_ISO_11785
# /wiki/ISO_20400
# /wiki/ISO/IEC_4909
# /wiki/ISO_9000
# /wiki/ISO_2014
# /wiki/International_Organization_for_Standardization
# /wiki/ISO_6438
# /wiki/ISO/IEC_21827
# /wiki/ISO_8691
# /wiki/ISO_9564
# /wiki/XML_Metadata_Interchange
# /wiki/International_Standard_Music_Number
# /wiki/ISO_3166
# /wiki/ISO_3166-1_numeric
# /wiki/Country_code
# /wiki/Semiconductor
# /wiki/ISBN_(identifier)
# /wiki/PDF/A
# /wiki/ArmSCII
# /wiki/QR_code
# /wiki/Knowledge_Discovery_Metamodel
# /wiki/JBIG
# /wiki/3GPP
# /wiki/Advanced_Mobile_Phone_System
# /wiki/List_of_mobile_phone_generations
# /wiki/Ultra-wideband
# /wiki/Doi_(identifier)
# /wiki/HTTP_proxy
# /wiki/Web_accelerator
# /wiki/Application_Delivery_Controller
# /wiki/Traffic_shaping
# /wiki/Gigabit_Ethernet
# /wiki/Modular_connector#8P8C_(8_position_8_contact)
# /wiki/Ethernet_over_twisted_pair
# /wiki/Category_3_cable
# /wiki/IBM
# /wiki/VMware
# /wiki/VMware_ESXi
# /wiki/Container_Linux#Overview
# /wiki/Open-source_software
# /wiki/Microbrewery
# /wiki/Ruble
# /wiki/Belarusian_ruble
# /wiki/Moldovan_leu
# /wiki/Principality_of_Moldavia
# /wiki/Early_Modern_Romania
# /wiki/Phanariotes
# /wiki/The_Apotheosis_of_Athanasios_Diakos
# /wiki/Impalement
# /wiki/Iglau
# /wiki/Poln%C3%A1
# /wiki/Hilsner_Affair
# /wiki/Charles_University
# /wiki/Gerhard_Gentzen
# /wiki/Natural_deduction
# /wiki/Free_logic
# /wiki/Quantifier_(logic)
# /wiki/Pronoun
# /wiki/Pronominal_adverb
# /wiki/Casally_modulated_preposition
# /wiki/Preposition_and_postposition
# /wiki/Varieties_of_Chinese
# /wiki/Clade
# /wiki/Strepsirrhini
# /wiki/Cartilage
# /wiki/Vascular_plant
# /wiki/Fern
# /wiki/Salviniales
# /wiki/Pilularia
# /wiki/Streptophyta
# /wiki/Coleochaetophyceae
# /wiki/Taxonomy_(biology)
# /wiki/Apomorphic
# /wiki/Mammals
# /wiki/Camouflage
# /wiki/William_Stephen_Raikes_Hodson
# /wiki/James_Leasor
# /wiki/ISBN_(identifier)
# /wiki/ISO_15926
# /wiki/Advanced_Video_Coding
# /wiki/ISO_11784_and_ISO_11785
# /wiki/Common_Criteria
# /wiki/IATF_16949
# /wiki/ISO/IEC_14651
# /wiki/CJK_Unified_Ideographs
# /wiki/ISO-IR-165#GB_8565.2
# /wiki/Unihan
# /wiki/Mac_OS_Celtic
# /wiki/Windows-1256
# /wiki/Mac_OS_S%C3%A1mi
# /wiki/Lotus_International_Character_Set
# /wiki/VT220
# /wiki/Star_coupler
# /wiki/TOPS-10
# /wiki/The_Ultimate_Entrepreneur
# /wiki/BASIC-8
# /wiki/Bill_Gates
# /wiki/Dwight_D._Eisenhower
# /wiki/United_States_Army_Europe
# /wiki/170th_Infantry_Brigade_(United_States)
# /wiki/Grow_the_Army
# /wiki/Fort_Bliss
# /wiki/Joint_Force_Land_Component_Commander
# /wiki/United_States_Armed_Forces
# /wiki/United_States_Intelligence_Community
# /wiki/Rocky_Mountains
# /wiki/Cabinet_of_the_United_States
# /wiki/Radio_in_the_United_States
# /wiki/Vice_President_of_the_United_States
# /wiki/Economy_of_the_United_States
# /wiki/List_of_tariffs_in_the_United_States
# /wiki/Revenue_Act_of_1934
# /wiki/Emergency_Internal_Revenue_Tax_Act
# /wiki/Revenue_Act_of_1918
# /wiki/Revenue_Act_of_1964
# /wiki/Tax_Adjustment_Act_of_1966
# /wiki/Deficit_Reduction_Act_of_1984
# /wiki/Tariff_of_1832
# /wiki/Tariff_of_1828
# /wiki/Tariff_of_1790
# /wiki/USS_Alexander_Hamilton
# /wiki/Statue_of_Alexander_Hamilton_(Chicago)
# /wiki/World_War_II
# /wiki/Home_Fleet
# /wiki/Commander-in-Chief,_China
# /wiki/Directorate_of_Naval_Tactical_and_Weapons_Policy
# /wiki/Directorate_of_Navigation_and_Tactical_Control_(Naval)
# /wiki/Directorate_of_Naval_Tactical_and_Weapons_Policy
# /wiki/Royal_Navy_Medical_Service
# /wiki/Commander-in-Chief,_Rosyth
# /wiki/Admiralty_Compass_Observatory
# /wiki/British_Admiralty
# /wiki/Christopher_Lloyd_(naval_historian)
# /wiki/Lincoln_College,_Oxford
# /wiki/Henry_Aldrich
# /wiki/Alwyn_Williams_(bishop)
# /wiki/John_Harmar
# /wiki/Henry_Dyson_Gabell
# /wiki/Henry_Dyson_Gabell
# /wiki/New_College,_Oxford
# /wiki/Department_of_Economics,_University_of_Oxford
# /wiki/Development_economics
# /wiki/PMID_(identifier)
# /wiki/Sci-Hub
# /wiki/BBC_News
# /wiki/BBC_South
# /wiki/List_of_BBC_properties
# /wiki/BBC_Radio
# /wiki/BBC_Radio_Nottingham
# /wiki/BBC_West_Midlands
# /wiki/North_Oxford
# /wiki/St_Antony%27s_College,_Oxford
# /wiki/Christ_Church,_Oxford
# /wiki/Zuleika_Dobson
# /wiki/List_of_fictional_Oxford_colleges
# /wiki/Ruth_Ware
# /wiki/Henry_James
# /wiki/Washington_Square_(novel)
# /wiki/What_Maisie_Knew
# /wiki/Edward_Wagenknecht
# /wiki/Theodore_Roosevelt
# /wiki/Expediting_Act
# /wiki/United_States_Army_War_College
# /wiki/Carlisle,_Pennsylvania
# /wiki/City_of_License
# /wiki/New_York_City
# /wiki/Constitution_of_the_United_States
# /wiki/Georgia_(U.S._state)
# /wiki/Amicalola_Falls_State_Park
# /wiki/McIntosh_Reserve
# /wiki/Chattahoochee_River
# /wiki/Odingsell_River
# /wiki/Lake_Jackson_(Georgia)
# /wiki/Flint_River_(Georgia)
# /wiki/Gulf_Coastal_Plain
# /wiki/Birmingham_District
# /wiki/Montgomery,_Alabama
# /wiki/Alabama_Shakespeare_Festival
# /wiki/Tuscaloosa_News
# /wiki/The_Herald_Democrat
# /wiki/Austin_American-Statesman
# /wiki/Public_Opinion_(Chambersburg)
# /wiki/The_Herald_(Glasgow)
# /wiki/Worcester_News
# /wiki/Green_Bay_Press-Gazette
# /wiki/The_Daily_Telegram
# /wiki/Leavenworth_Times
# /wiki/Casual_Living
# /wiki/The_Gaston_Gazette
# /wiki/Finance_%26_Commerce
# /wiki/Henderson_Gleaner
# /wiki/The_McDonough_County_Voice
# /wiki/Long_Island_Business_News
# /wiki/The_Dispatch_(Lexington)
# /wiki/The_Alliance_Review
# /wiki/The_Rolla_Daily_News
# /wiki/The_Daily_Leader
# /wiki/Pontiac,_Illinois
# /wiki/Emington,_Illinois
# /wiki/Reddick,_Illinois
# /wiki/Essex_Township,_Kankakee_County,_Illinois
# /wiki/Bradley,_Illinois
# /wiki/Rockford_metropolitan_area,_Illinois
# /wiki/Detroit%E2%80%93Windsor
# /wiki/Crime_in_Detroit
# /wiki/2022_Detroit_shootings
# /wiki/List_of_homicides_in_Michigan
# /wiki/Dansville,_Michigan
# /wiki/U.S._state
# /wiki/State_auditor
# /wiki/State_Auditor_of_South_Dakota
# /wiki/Bibliography_of_South_Dakota_history
# /wiki/Clay_County,_South_Dakota
# /wiki/Sanborn_County,_South_Dakota
# /wiki/1950_United_States_census
# /wiki/Alabama
# /wiki/Dothan_metropolitan_area,_Alabama
# /wiki/Limestone_County,_Alabama
# /wiki/Ridge-and-Valley_Appalachians
# /wiki/Worth_County,_Georgia
# /wiki/Baker_County,_Georgia
# /wiki/Clarke_County,_Georgia
# /wiki/Music_of_Georgia_(U.S._state)
# /wiki/Southwest_Georgia
# /wiki/Upson_County,_Georgia
# /wiki/1968_United_States_presidential_election_in_Georgia
# /wiki/1944_United_States_presidential_election_in_Georgia
# /wiki/Primary_election
# /wiki/Gerrymandering
# /wiki/United_Kingdom
# /wiki/Lewiston,_New_York
# /wiki/Burt,_New_York
# /wiki/Raymond,_New_York
# /wiki/Lockport_(city),_New_York#Notable_people
# /wiki/Chase-Hubbard-Williams_House
# /wiki/National_Register_of_Historic_Places_listings_in_Staten_Island
# /wiki/National_Register_of_Historic_Places_listings_in_Syracuse,_New_York
# /wiki/Horatio_Nelson_White
# /wiki/Plymouth_Congregational_Church_(Syracuse,_New_York)
# /wiki/National_Register_of_Historic_Places_listings_in_Rochester,_New_York
# /wiki/St._Mary%27s_Roman_Catholic_Church_and_Rectory
# /wiki/National_Register_of_Historic_Places_listings_in_southern_Westchester_County,_New_York
# /wiki/United_States
# /wiki/Islamic_terrorism
# /wiki/Palestinian_political_violence
# /wiki/Fathi_Shaqaqi
# /wiki/Israel
# /wiki/1964_AFC_Asian_Cup
# /wiki/1956_AFC_Asian_Cup
# /wiki/1996_AFC_Asian_Cup_Final
# /wiki/Zayed_Sports_City_Stadium
# /wiki/Sultan_Qaboos_Sports_Complex
# /wiki/Oman
# /wiki/2011_FIFA_Beach_Soccer_World_Cup_qualification_(AFC)
# /wiki/Muscat,_Oman
# /wiki/Church_of_the_East
# /wiki/Nestorianism
# /wiki/Christian_mysticism
# /wiki/Teresa_of_%C3%81vila
# /wiki/Decretum_Gratiani
# /wiki/Martin_Luther
# /wiki/C._F._W._Walther
# /wiki/St._Louis,_Missouri
# /wiki/MetroLink_(St._Louis)
# /wiki/ISBN_(identifier)
# /wiki/PDF/UA
# /wiki/ISO_10303
# /wiki/International_Bank_Account_Number
# /wiki/COLLADA
# /wiki/Common_Logic
# /wiki/Notation3
# /wiki/Syntactic_sugar
# /wiki/ISBN_(identifier)
# /wiki/ISO/IEC_17024
# /wiki/ISO_3166
# /wiki/MARC_standards
# /wiki/Postcodes_in_New_Zealand
# /wiki/Palmerston_North
# /wiki/South_Island
# /wiki/Department_of_Corrections_(New_Zealand)
# /wiki/National_Emergency_Management_Agency_(New_Zealand)
# /wiki/Statue_of_John_Robert_Godley
# /wiki/Charles_Bowen_(New_Zealand_politician)
# /wiki/Speaker_of_the_New_Zealand_Legislative_Council
# /wiki/New_Zealand_Legislative_Council_(1841%E2%80%931853)
# /wiki/New_Zealand_House_of_Representatives
# /wiki/Parliament_House,_Wellington
# /wiki/General_Assembly_House
# /wiki/Members_of_Parliament
# /wiki/Teachta_D%C3%A1la
# /wiki/Euro
# /wiki/50_euro_cent_coin
# /wiki/Luc_Luycx
# /wiki/Medallist
# /wiki/Academy
# /wiki/Soviet_Union
# /wiki/Nabat#Decline
# /wiki/Direct_democracy
# /wiki/Utah
# /wiki/Antelope_Island
# /wiki/List_of_Utah_state_parks
# /wiki/Deep_Creek_North_Wilderness
# /wiki/Escalante_Petrified_Forest_State_Park
# /wiki/National_Landscape_Conservation_System
# /wiki/Montana
# /wiki/List_of_U.S._state_minerals,_rocks,_stones_and_gemstones
# /wiki/Rose_rock
# /wiki/Garber_Sandstone
# /wiki/Permian
# /wiki/Journal_of_Geophysical_Research
# /wiki/American_Geophysical_Union
# /wiki/Planetary_science
# /wiki/Astrobiology
# /wiki/Helium_hydride_ion
# /wiki/Micrometre
# ...
# /wiki/Common_Development_and_Distribution_License
# /wiki/Ubuntu_(operating_system)
# /wiki/NimbleX
# /wiki/USB
# /wiki/Storage_Module_Device
# /wiki/PC_Card
# /wiki/3Com
# /wiki/%C3%89ric_Benhamou
# /wiki/Lyc%C3%A9e_Champollion
# /wiki/Lyc%C3%A9e_Stendhal
# /wiki/Meylan
# /wiki/Pontcharra
# /wiki/Saint-Martin-d%27Uriage
# /wiki/Thodure
# /wiki/Torchefelon
# /wiki/Aoste,_Is%C3%A8re
# /wiki/Sillans
# /wiki/Romagnieu
# /wiki/Vernas
# /wiki/Cour-et-Buis
# /wiki/Anthon,_Is%C3%A8re
# /wiki/S%C3%A9chilienne
# /wiki/France
# /wiki/Eurozone
# /wiki/Vatican_City
# /wiki/List_of_current_cardinals
# /wiki/Ant%C3%B3nio_Augusto_dos_Santos_Marto
# /wiki/Congregation_for_Divine_Worship_and_the_Discipline_of_the_Sacraments
# /wiki/Ecclesia_de_Eucharistia
# /wiki/List_of_pastoral_visits_of_Pope_John_Paul_II
# /wiki/Paola,_Calabria
# /wiki/Acquaformosa
# /wiki/San_Demetrio_Corone
# /wiki/Italy
# /wiki/Istrian_Italians
# /wiki/Pula
# /wiki/Solin,_Croatia
# /wiki/Lateran
# /wiki/Holy_See
# /wiki/Armenian_Patriarchate_of_Jerusalem
# /wiki/Church_of_Alexandria
# /wiki/List_of_abunas_of_Ethiopia
# /wiki/Ethiopian_ecclesiastical_titles
# /wiki/Council_of_Ephesus
# /wiki/Sign_of_the_cross#Eastern_Orthodoxy
# /wiki/ILY_sign
# /wiki/New_Zealand_Sign_Language
# /wiki/Zambian_Sign_Language
# /wiki/Stokoe_notation
# /wiki/Javanese_script
# /wiki/Odia_script
# /wiki/Naoriya_script
# /wiki/Brahmic_scripts
# /wiki/Ideogram
# /wiki/Cartography
# /wiki/Charles-Ren%C3%A9_de_Fourcroy
# /wiki/Charles_Booth_(social_reformer)
# /wiki/Udny_Yule
# /wiki/Frank_Yates
# /wiki/Malvern_College
# /wiki/Colwall
# /wiki/Herefordshire
# /wiki/Bath_and_North_East_Somerset
# /wiki/Unitary_authorities_of_England
# /wiki/Shropshire_(district)
# /wiki/Darlington_Borough_Council_elections
# /wiki/Stockton-on-Tees_Borough_Council_elections
# /wiki/Conservative_Party_(UK)
# /wiki/British_Asians
# /wiki/British_Asians_in_association_football
# /wiki/Southend_United_F.C.
# /wiki/Watford_F.C.
# /wiki/Premier_League
# /wiki/Burnley_F.C.
# /wiki/Brighton_%26_Hove_Albion_F.C.
# /wiki/Royal_Spanish_Football_Federation
# /wiki/FIFA_Confederations_Cup
# /wiki/American_Samoa_national_football_team
# /wiki/Australia_31%E2%80%930_American_Samoa
# /wiki/2002_FIFA_World_Cup_qualification_%E2%80%93_CONCACAF_Caribbean/Central_American_Play-offs
# /wiki/2002_FIFA_World_Cup_qualification_(CONMEBOL)
# /wiki/Argentina_national_football_team
# /wiki/Udinese_Calcio
# /wiki/Vittorio_Faroppa
# /wiki/Elvio_Banchero
# /wiki/Mario_Magnozzi
# /wiki/Zden%C4%9Bk_Zeman
# /wiki/La_Gazzetta_dello_Sport
# /wiki/Il_manifesto
# /wiki/Fanpage.it
# /wiki/Primorski_dnevnik
# /wiki/Slovene_minority_in_Italy
# /wiki/Franc_Kav%C4%8Di%C4%8D
# /wiki/Judgment_of_Solomon
# /wiki/Nuremberg_Chronicle
# /wiki/Bayerische_Staatsbibliothek
# /wiki/German_Mediatisation#Secularisation
# /wiki/Nesselrode
# /wiki/Thaler
# /wiki/Reichsm%C3%BCnzordnung
# /wiki/Currency
# /wiki/Cheque_clearing
# /wiki/Savings_bank
# /wiki/Islamic_banking_and_finance
# /wiki/Islamic_marriage_contract
# /wiki/Mofsed-e-filarz
# /wiki/Fasad
# /wiki/Riba
# /wiki/Islamic_banking_and_finance
# /wiki/Transaction_account
# /wiki/Giro_(banking)
# /wiki/Deposit_account
# /wiki/Double-entry_bookkeeping_system
# /wiki/Luca_Pacioli
# /wiki/List_of_Catholic_churchmen-scientists
# /wiki/Tonograph
# /wiki/Naples
# /wiki/Kingdom_of_the_Two_Sicilies
# /wiki/Adriatic_Veneti
# /wiki/Breton_mythology
# /wiki/Names_of_the_Celts
# /wiki/Proto-Celtic_language
# /wiki/Indicative_mood
# /wiki/Modern_English
# /wiki/British_English
# /wiki/English_language_in_Southern_England
# /wiki/London
# /wiki/London_Stock_Exchange
# /wiki/United_Kingdom_company_law
# /wiki/Canary_Wharf
# /wiki/London_Overground
# /wiki/Sadiq_Khan
# /wiki/Joanne_McCartney
# /wiki/2016_London_Assembly_election
# /wiki/London_Conservatives
# /wiki/Horace_Cutler
# /wiki/Andrew_McIntosh,_Baron_McIntosh_of_Haringey
# /wiki/Scotland_Office
# /wiki/2022_Northern_Ireland_Assembly_election
# /wiki/Democratic_Unionist_Party
# /wiki/Social_Democratic_and_Labour_Party
# /wiki/1998_Northern_Ireland_Assembly_election
# /wiki/1998_Knowsley_Metropolitan_Borough_Council_election
# /wiki/1938_Liverpool_City_Council_election
# /wiki/Conservative_Party_(UK)
# /wiki/Donald_Trump
# /wiki/Team_of_Vipers
# /wiki/Las_Vegas_(In_the_Hills_of_Donegal)
# /wiki/Cultural_depictions_of_Melania_Trump
# /wiki/Trump_101
# /wiki/Post-election_lawsuits_related_to_the_2020_United_States_presidential_election_from_Georgia
# /wiki/Georgia_Superior_Courts
# /wiki/Mandamus
# /wiki/Cheney_v._United_States_District_Court
# /wiki/Antonin_Scalia
# /wiki/City_of_Richmond_v._J.A._Croson_Co.
# /wiki/Nevada_Department_of_Human_Resources_v._Hibbs
# /wiki/List_of_United_States_Supreme_Court_cases,_volume_538
# /wiki/List_of_United_States_Supreme_Court_cases,_volume_583
# /wiki/List_of_United_States_Supreme_Court_cases,_volume_325
# /wiki/List_of_United_States_Supreme_Court_cases,_volume_567
# /wiki/List_of_United_States_Supreme_Court_cases,_volume_10
# /wiki/List_of_United_States_Supreme_Court_cases,_volume_355
# /wiki/List_of_United_States_Supreme_Court_cases,_volume_180
# /wiki/List_of_United_States_Supreme_Court_cases,_volume_173
# /wiki/List_of_United_States_Supreme_Court_cases,_volume_280
# /wiki/Chief_Justice_of_the_United_States
# /wiki/Congressional_Quarterly
# /wiki/United_States_Senate_chamber
# /wiki/111th_United_States_Congress
# /wiki/Fair_Sentencing_Act
# /wiki/Wayback_Machine
# /wiki/Long_Now_Foundation
# /wiki/Geologic_time_scale
# /wiki/Frasnian
# /wiki/Jules_Gosselet
# /wiki/Ardennes
# /wiki/World_War_I
# /wiki/Battle_of_Megiddo_(1918)
# /wiki/Sinai_and_Palestine_campaign
# /wiki/Rafah
# /wiki/Al-Arroub_(camp)
# /wiki/Siege_of_Tel_al-Zaatar
# /wiki/Kafr_Qasim_massacre
# /wiki/Menachem_Begin
# /wiki/1964_Nobel_Peace_Prize
# /wiki/Mexico
# /wiki/Juan_Vicente_de_G%C3%BCemes,_2nd_Count_of_Revillagigedo
# /wiki/Maria_Louisa_of_Parma
# /wiki/Princess_Maria_Antonia_of_Naples_and_Sicily
# /wiki/Princess_Cristina_of_Bourbon-Two_Sicilies
# /wiki/Prince_Pedro,_Duke_of_Calabria
# /wiki/Infante_Carlos,_Duke_of_Calabria
# /wiki/Charles_Ferdinand,_Prince_of_Capua
# /wiki/Ferdinand_I_of_the_Two_Sicilies
# /wiki/Philip_II_of_Spain
# /wiki/Neapolitan_sums
# /wiki/Monogram
# /wiki/Europe
# /wiki/Mediterranean_Basin
# /wiki/Chamaerops
# /wiki/Lytocaryum
# /wiki/Arecales
# /wiki/Cucurbitales
# /wiki/Proceedings_of_the_Royal_Society_B
# /wiki/Impact_factor
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISO_11940-2
# /wiki/ISO_5426
# /wiki/IATF_16949
# /wiki/ISO_20400
# /wiki/Linux_Standard_Base
# /wiki/ISO/IEC_10967
# /wiki/ISO_216
# /wiki/Simple_Features
# /wiki/DE-9IM
# /wiki/Reflexive_relation
# /wiki/Preorder
# /wiki/Simulation_preorder
# /wiki/Disjoint_union
# /wiki/Venn_diagram
# /wiki/Model_theory
# /wiki/Encyclopedia_of_Mathematics
# /wiki/ISBN_(identifier)
# /wiki/Uniform_Resource_Name
# /wiki/Info_URI_scheme
# /wiki/Uniform_Resource_Identifier
# /wiki/Magnet_URI_scheme
# /wiki/Backup
# /wiki/Doi_(identifier)
# /wiki/ISO_3166-3
# /wiki/Germany
# /wiki/Stem_duchy
# /wiki/Low_Franconian
# /wiki/Hindeloopen_Frisian
# /wiki/Indo-European_languages
# /wiki/Proto-Slavic
# /wiki/Cornish_mythology
# /wiki/Boskednan_stone_circle
# /wiki/Ardgroom
# /wiki/Stanton_Drew_stone_circles
# /wiki/Bristol
# /wiki/ISBN_(identifier)
# /wiki/ISO_19092-1
# /wiki/Graphical_Kernel_System
# /wiki/ISO/IEC_8859-5
# /wiki/ISO/IEC_8859-7
# /wiki/Code_page_770
# /wiki/Digital_encoding_of_APL_symbols
# /wiki/Code_page
# /wiki/Mazovia_encoding
# /wiki/Code_page_895
# /wiki/Mac_OS_Icelandic_encoding
# /wiki/Mac_OS_Central_European_encoding
# /wiki/%E2%88%82
# /wiki/Integral_sign
# /wiki/Contour_integral
# /wiki/Common_integrals_in_quantum_field_theory
# /wiki/Branches_of_physics
# /wiki/Special_relativity
# /wiki/Astrophysical_jet
# /wiki/Special_relativity
# /wiki/The_World_as_I_See_It_(book)
# /wiki/Albert_Einstein_Medal
# /wiki/Equivalence_principle
# /wiki/Einstein_for_Beginners
# /wiki/Hans_Albert_Einstein
# /wiki/American_Society_of_Civil_Engineers
# /wiki/Architectural_Engineering_Institute
# /wiki/Professional_engineering
# /wiki/Turkey
# /wiki/Sakha
# /wiki/Sea_of_Okhotsk
# /wiki/Kamchatka_Peninsula
# /wiki/Pirate_Coast
# /wiki/ISBN_(identifier)
# /wiki/ISO/IEC_10967
# /wiki/ISO/IEC_9797-1
# /wiki/ISO_2711
# /wiki/Advanced_Video_Coding
# /wiki/Progressive_Graphics_File
# /wiki/JBIG
# /wiki/Half_Rate
# /wiki/Musepack
# /wiki/ICER
# /wiki/G.726
# /wiki/Enhanced_Variable_Rate_Codec
# /wiki/Huffman_coding
# /wiki/Bernoulli_process
# /wiki/Ergodicity
# /wiki/Ergodic_theory
# /wiki/JSTOR_(identifier)
# /wiki/Wayback_Machine
# /wiki/Sloan_Foundation
# /wiki/WNET
# /wiki/WLIW_(TV)
# /wiki/Nova_(American_TV_program)
# /wiki/History_Detectives
# /wiki/Pittsburgh_Post-Gazette
# /wiki/Liberalism_in_the_United_States
# /wiki/Benito_Ju%C3%A1rez
# /wiki/Ignacio_Comonfort
# /wiki/Oil_painting#Oil_on_canvas
# /wiki/Pigments
# /wiki/Prehistoric_art
# /wiki/Serbia
# /wiki/Nemanja_Mati%C4%87
# /wiki/Diego_Llorente
# /wiki/2012%E2%80%9313_Segunda_Divisi%C3%B3n_B
# /wiki/Miguel_%C3%81ngel_Guerrero_Mart%C3%ADn
# /wiki/Andreas_Chrysostomou
# /wiki/Samuel_Mr%C3%A1z
# /wiki/Slovak_First_Football_League
# /wiki/Jozef_Ko%C5%BElej
# /wiki/2007%E2%80%9308_Slovak_Superliga
# /wiki/2007%E2%80%9308_Serbian_SuperLiga
# /wiki/2007%E2%80%9308_Azerbaijan_Premier_League
# /wiki/FK_Standard_Sumgayit
# /wiki/Neft%C3%A7i_PFK
# /wiki/Vali_Gasimov
# /wiki/FC_Spartak_Moscow
# /wiki/Yevgeni_Bushmanov
# /wiki/Yuriy_Nikiforov
# /wiki/Russia_national_football_team
# /wiki/UEFA_Euro_1996_Group_C
# /wiki/We%27re_in_This_Together_(Simply_Red_song)
# /wiki/AllMusic
# /wiki/List_of_online_music_databases
# /wiki/Jamendo
# /wiki/Ovi_(Nokia)
# /wiki/India
# /wiki/Arts_and_entertainment_in_India
# /wiki/Social_issue#India
# /wiki/Hate_crime
# /wiki/Hate_Crime_Statistics_Act
# /wiki/United_States_Senate_Committee_on_the_Judiciary
# /wiki/Georgia_(U.S._state)
# /wiki/Macon,_Georgia
# /wiki/Monroe_Railroad_and_Banking_Company
# /wiki/Atlanta
# /wiki/Preston,_Georgia
# /wiki/ZIP_code
# /wiki/Maine
# /wiki/1920_United_States_census
# /wiki/Midwestern_United_States
# /wiki/Doi_(identifier)
# /wiki/Semantic_interoperability
# /wiki/Vocabulary
# /wiki/Distant_reading
# /wiki/Computer-assisted_reviewing
# /wiki/XML
# /wiki/Datatype
# /wiki/Type_system
# /wiki/Interpreter_(computing)
# /wiki/Computer_science
# /wiki/Human%E2%80%93computer_interaction
# /wiki/Eating_disorder
# /wiki/Psychogenic_pain
# /wiki/Impulse-control_disorder
# /wiki/Frontotemporal_dementia
# /wiki/Cluttering
# /wiki/Psychiatry
# /wiki/PMID_(identifier)
# /wiki/Annals_of_Surgery
# /wiki/Medical_journal
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISO/IEC_20000
# /wiki/ISO/TR_11941
# /wiki/Prolog
# /wiki/YAP_(Prolog)
# /wiki/Prolog
# /wiki/ISO_2014
# /wiki/ISO_128
# /wiki/ISO_22300
# /wiki/ISO_10007
# /wiki/JPEG_XS
# /wiki/Comparison_of_video_codecs
# /wiki/Nero_Digital
# /wiki/MSU_Lossless_Video_Codec
# /wiki/QuickTime_File_Format
# /wiki/Musepack
# /wiki/Helix_(multimedia_project)
# /wiki/JetAudio
# /wiki/QuickTime
# /wiki/Graphics_Interchange_Format
# /wiki/RGB
# /wiki/Photoreceptor_cell
# /wiki/Schwann_cell
# /wiki/Photoreceptor_cell
# /wiki/Resting_potential
# /wiki/Membrane_potential
# /wiki/ISSN_(identifier)
# /wiki/ISO/IEC_8859-10
# /wiki/Z
# /wiki/Z_with_stroke
# /wiki/Sz_(digraph)
# /wiki/L
# /wiki/%E1%B8%B8
# /wiki/A_(Indic)
# /wiki/Vedic_Extensions
# /wiki/Veda
# /wiki/Rigveda
# /wiki/Avesta
# /wiki/Sasanian_Empire
# /wiki/Byzantine%E2%80%93Sasanian_War_of_440
# /wiki/Roman%E2%80%93Parthian_Wars
# /wiki/Nisa,_Turkmenistan
# /wiki/Merke_Turkic_Sanctuaries
# /wiki/Jambyl_Province
# /wiki/Romanization_of_Russian
# /wiki/Latinisation_(USSR)
# /wiki/Selkup_language
# /wiki/Language_family
# /wiki/Cahuapanan_languages
# /wiki/Cariban_languages
# /wiki/C%C3%A9sar_River
# /wiki/Magdalena_River
# /wiki/River
# /wiki/Plastic
# /wiki/Surgery
# /wiki/PMID_(identifier)
# /wiki/Journal_ranking
# /wiki/SCImago_Journal_Rank
# /wiki/Least_publishable_unit
# /wiki/Imprint_(trade_name)
# /wiki/Working_paper
# /wiki/Scholarly_communication
# /wiki/Technical_report
# /wiki/Thesis
# /wiki/List_of_style_guides#Academic
# /wiki/American_Chemical_Society
# /wiki/Journal_of_the_American_Society_for_Mass_Spectrometry
# /wiki/Academic_publishing
# /wiki/Doi_(identifier)
# /wiki/ISO_4157
# /wiki/ISO_10303-21
# /wiki/ISO/IEC_8859-2
# /wiki/B
# /wiki/N
# /wiki/International_Phonetic_Alphabet
# /wiki/Labialization
# /wiki/Abaza_language
# /wiki/List_of_Cyrillic_digraphs_and_trigraphs#Г
# /wiki/%D0%A5
# /wiki/En_with_descender
# /wiki/Short_I_with_tail
# /wiki/Schwa_with_diaeresis
# /wiki/Yu_(Cyrillic)
# /wiki/O_with_macron_(Cyrillic)
# /wiki/Uk_(Cyrillic)
# /wiki/We_(Cyrillic)
# /wiki/Twe
# /wiki/Soft_sign
# /wiki/Ge_(Cyrillic)
# /wiki/Je_(Cyrillic)
# /wiki/O_with_open_bottom
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 17
#      15 newArticle = links[random.randint(0, len(links)-1)].attrs['href']
#      16 print(newArticle)
# ---> 17 links = getLinks(newArticle)
#
# Cell In[3], line 9, in getLinks(articleUrl)
#       8 def getLinks(articleUrl):
# ----> 9     html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
#      10     bs = BeautifulSoup(html, 'html.parser')
#      11     return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))
#
# File c:\Users\josef\anaconda3\envs\opencv\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\josef\anaconda3\envs\opencv\lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File c:\Users\josef\anaconda3\envs\opencv\lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File c:\Users\josef\anaconda3\envs\opencv\lib\urllib\request.py:557, in OpenerDirector.error(self, proto, *args)
#     555     http_err = 0
#     556 args = (dict, proto, meth_name) + args
# --> 557 result = self._call_chain(*args)
#     558 if result:
#     559     return result
#
# File c:\Users\josef\anaconda3\envs\opencv\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\josef\anaconda3\envs\opencv\lib\urllib\request.py:749, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     746 fp.read()
#     747 fp.close()
# --> 749 return self.parent.open(new, timeout=req.timeout)
#
# File c:\Users\josef\anaconda3\envs\opencv\lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File c:\Users\josef\anaconda3\envs\opencv\lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File c:\Users\josef\anaconda3\envs\opencv\lib\urllib\request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File c:\Users\josef\anaconda3\envs\opencv\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\josef\anaconda3\envs\opencv\lib\urllib\request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# ## Recursively crawling an entire site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')

# %% [markdown]
# ## Collecting Data Across an Entire Site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print(bs.h1.get_text())
        print(bs.find(id ='mw-content-text').find_all('p')[0])
        print(bs.find(id='ca-edit').find('span').find('a').attrs['href'])
    except AttributeError:
        print('This page is missing something! Continuing.')
    
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print('-'*20)
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')

# %% [markdown]
# ## Crawling across the Internet

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

pages = set()
random.seed(datetime.datetime.now())

#Retrieves a list of all Internal links found on a page
def getInternalLinks(bs, includeUrl):
    includeUrl = '{}://{}'.format(urlparse(includeUrl).scheme, urlparse(includeUrl).netloc)
    internalLinks = []
    #Finds all links that begin with a "/"
    for link in bs.find_all('a', href=re.compile('^(/|.*'+includeUrl+')')):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                if(link.attrs['href'].startswith('/')):
                    internalLinks.append(includeUrl+link.attrs['href'])
                else:
                    internalLinks.append(link.attrs['href'])
    return internalLinks
            
#Retrieves a list of all external links found on a page
def getExternalLinks(bs, excludeUrl):
    externalLinks = []
    #Finds all links that start with "http" that do
    #not contain the current URL
    for link in bs.find_all('a', href=re.compile('^(http|www)((?!'+excludeUrl+').)*$')):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])
    return externalLinks

def getRandomExternalLink(startingPage):
    html = urlopen(startingPage)
    bs = BeautifulSoup(html, 'html.parser')
    externalLinks = getExternalLinks(bs, urlparse(startingPage).netloc)
    if len(externalLinks) == 0:
        print('No external links, looking around the site for one')
        domain = '{}://{}'.format(urlparse(startingPage).scheme, urlparse(startingPage).netloc)
        internalLinks = getInternalLinks(bs, domain)
        return getRandomExternalLink(internalLinks[random.randint(0,
                                    len(internalLinks)-1)])
    else:
        return externalLinks[random.randint(0, len(externalLinks)-1)]
    
def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print('Random external link is: {}'.format(externalLink))
    followExternalOnly(externalLink)
            
followExternalOnly('http://oreilly.com')

# %% [markdown]
# ## Collect all External Links from a Site

# %%
# Collects a list of all external URLs found on the site
allExtLinks = set()
allIntLinks = set()


def getAllExternalLinks(siteUrl):
    html = urlopen(siteUrl)
    domain = '{}://{}'.format(urlparse(siteUrl).scheme,
                              urlparse(siteUrl).netloc)
    bs = BeautifulSoup(html, 'html.parser')
    internalLinks = getInternalLinks(bs, domain)
    externalLinks = getExternalLinks(bs, domain)

    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.add(link)
            print(link)
    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.add(link)
            getAllExternalLinks(link)


allIntLinks.add('http://oreilly.com')
getAllExternalLinks('http://oreilly.com')
