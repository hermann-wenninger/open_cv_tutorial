# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.normal(10,5,100)
y = 3 + .5*x + np.random.normal(0,1,100)
myvec = np.array([x,y])
plt.plot(myvec[0,],myvec[1,],'ro')
plt.show()

# %%
d_vectors = [(6, 4), (3, 1), (1, 2), (-1, 5), (-2,5), (-3,4), (-4,4), 
    (-5,3), (-5,2), (-2,2), (-5,1), (-4,0), (-2,1), (-1,0), (0,-3), 
    (-1,-4), (1,-4), (2,-3), (1,-2), (3,-1), (5,1)
]

# %%
[i[0] for i in d_vectors],[i[1] for i in d_vectors]
plt.plot([i[0] for i in d_vectors],[i[1] for i in d_vectors],'ro')
plt.plot([i[0] for i in d_vectors],[i[1] for i in d_vectors])
plt.show()

# %%
def add(vectors):
    return (sum([v[0] for v  in vectors]), sum([v[1] for v  in vectors]))

# %%
def translate(translation, vectors):
    return [add(translation, v) for v  in vectors]

# %%
def draw(d_vectors=d_vectors):
    plt.plot([i[0] for i in d_vectors],[i[1] for i in d_vectors],'ro')
    plt.plot([i[0] for i in d_vectors],[i[1] for i in d_vectors])
    plt.show()

draw(d_vectors)

# %%
def hundred_dinos(d_vectors):
    translations = [(12*x,10*y) 
                    for x in range(-5,5) 
                    for y in range(-5,5)]
    dinos = [(translate(t, d_vectors))for t in translations]
    print(translations)
    print(len(dinos))
    draw(dinos)
    
 
hundred_dinos(d_vectors)

def base_vector_translation(base_vector):
    translations = [(12*x,10*y) for x in range(-5,5) for y in range(-5,5)]
    for i in range(len(translations)):
        for j in range(len(base_vector)):
# Out:
# [(-60, -50), (-60, -40), (-60, -30), (-60, -20), (-60, -10), (-60, 0), (-60, 10), (-60, 20), (-60, 30), (-60, 40), (-48, -50), (-48, -40), (-48, -30), (-48, -20), (-48, -10), (-48, 0), (-48, 10), (-48, 20), (-48, 30), (-48, 40), (-36, -50), (-36, -40), (-36, -30), (-36, -20), (-36, -10), (-36, 0), (-36, 10), (-36, 20), (-36, 30), (-36, 40), (-24, -50), (-24, -40), (-24, -30), (-24, -20), (-24, -10), (-24, 0), (-24, 10), (-24, 20), (-24, 30), (-24, 40), (-12, -50), (-12, -40), (-12, -30), (-12, -20), (-12, -10), (-12, 0), (-12, 10), (-12, 20), (-12, 30), (-12, 40), (0, -50), (0, -40), (0, -30), (0, -20), (0, -10), (0, 0), (0, 10), (0, 20), (0, 30), (0, 40), (12, -50), (12, -40), (12, -30), (12, -20), (12, -10), (12, 0), (12, 10), (12, 20), (12, 30), (12, 40), (24, -50), (24, -40), (24, -30), (24, -20), (24, -10), (24, 0), (24, 10), (24, 20), (24, 30), (24, 40), (36, -50), (36, -40), (36, -30), (36, -20), (36, -10), (36, 0), (36, 10), (36, 20), (36, 30), (36, 40), (48, -50), (48, -40), (48, -30), (48, -20), (48, -10), (48, 0), (48, 10), (48, 20), (48, 30), (48, 40)]
# 100
